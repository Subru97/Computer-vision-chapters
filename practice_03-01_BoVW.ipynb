# %% [markdown]
# EPITA 2020 MLRF practice_03-01_BoVW v2020-07-02_113744 by Joseph CHAZALON
#
# <div style="overflow: auto; padding: 10px; margin: 10px 0px">
# <img alt="Creative Commons License" src='img/CC-BY-4.0.png' style='float: left; margin-right: 20px'>
#
# This work is licensed under a [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0/).
# </div>

# %% [markdown]
# # Practice 04 part 01: Bag of Visual Words search engine
#
# We will demonstrate how to use this classical technique to build a global descriptor from local descriptors.
#
# In this session, you will learn how to produce results like the ones displayed below (left column: queries, other columns: responses to query in the same row).
#
# ![Sample output](img/practice_04/sample_results.jpg)
#
#
# We will proceed in 9 steps:
#
# 1. Sample some descriptors for codebook learning
# 2. Learn normalisation parameters for descriptors (mean and eigenvectors)
# 3. Use k-Means to learn a codebook
# 4. Compute the BoVW vector for each image
# 5. Setup a nearest neighbors search structure
# 6. Evaluate our approach using mean average precision
# 7. Display some results
# 8. Compute the best results for the test queries
# 9. Export the results for the test queries (and submit them for grading).
#
#
# ## Resources
# The resources for this session are distributed as a separate archive.
# Here is a summary of the files we provide:
# - `jpg/*.jpg`: 1491 images;
# - `thumbs/*.jpg`: image thumbnails for fast display;
# - `siftgeo/*.siftgeo`: associated pre-computed SIFT descriptors for each image;
# - `gt_student.json`: a partial ground truth to enable a partial evaluation of the retrieval;
# - `queries_for_grading.json`: a list of queries for which you need to submit your results.
#
#
# ## Ground truth format
# The ground truth file is a JSON file. Here is an except:
# ```json
# {
#  "90314": [
#   "90989",
#   "91259"
#  ],
#  "90376": [
#   "90674"
#  ],
#  ...
# }
# ```
# It contains a dictionary which associates to each query the list of relevant elements.
# Every value is a string representing an image identifier, ie the part of the image or descriptor file without extension.
#
# Example: `"90314"` is the identifier
# of the image `jpgs/90314.jpg`
# with descriptors available at `siftgeo/90314.siftgeo`
# and its thumbnail is `thumbs/90314.jpg`.
#
# Looking at the previous excerpt, we can see that the query `90314` has two relevant results: `90989` and `91259`.
#
#
# ## Local descriptors
# We provide precomputed SIFT descriptors to save you time.
# We also provide a commodity function to help you load them (see below).

# %% [markdown]
# ## 0. Import module, load resources

# %%
# deactivate buggy jupyter completion (only if completion is very slow)
# %config Completer.use_jedi = False

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
# FIXME setup the resources location
PATH_TO_RESOURCES = "..\\inria_holidays_shuffled_student"

# %% [markdown]
# ## Code to read descriptors
# We provide you with the `siftgeo_read_desc(path)` function which reads the list of descriptors stored in a `.siftgeo` file.

# %%
SIFTGEO_DTYPE = np.dtype([
    ("x", "<f4"),
    ("y", "<f4"),
    ("scale", "<f4"),
    ("angle", "<f4"),
    ("mi11", "<f4"),
    ("mi12", "<f4"),
    ("mi21", "<f4"),
    ("mi22", "<f4"),
    ("cornerness", "<f4"),
    ("desdim", "<i4"),
    ("component", "<u1", 128)
])

def siftgeo_read_full(path):
    return np.fromfile(path, dtype=SIFTGEO_DTYPE)

def siftgeo_read_desc(path):
    desc = siftgeo_read_full(path)["component"]
    if desc.size == 0: 
        desc = np.zeros((0, 128), dtype = 'uint8')
    return desc

# %% [markdown]
# ## Some of utility listings
# Again, to save you time, here are some useful lists and mappings:
# - `IMG_NAMES_FULL`: list of all full images paths
# - `IMG_IDS`: list of image ids (filename without directories nor extension)
# - `imgid_to_index`: a mapping from image ids (like `'90000'`, `'90001'`, `'90002'` or `'90003'` — note the quotes indicating string types) to an absolute index in the image list (like `0`, `1`, `2` or `3` — integers). **This will be useful to convert between image paths and rows in the global index.**

# %%
# IMG_NAMES_FULL = !ls $PATH_TO_RESOURCES/thumbs/*.jpg | sort
# len(IMG_NAMES_FULL), IMG_NAMES_FULL[:5]

import glob
IMG_NAMES_FULL = glob.glob(PATH_TO_RESOURCES+"\\thumbs\\*.jpg")
len(IMG_NAMES_FULL), IMG_NAMES_FULL[:5]
# Out:
# (1491,
#  ['..\\inria_holidays_shuffled_student\\thumbs\\90000.jpg',
#   '..\\inria_holidays_shuffled_student\\thumbs\\90001.jpg',
#   '..\\inria_holidays_shuffled_student\\thumbs\\90002.jpg',
#   '..\\inria_holidays_shuffled_student\\thumbs\\90003.jpg',
#   '..\\inria_holidays_shuffled_student\\thumbs\\90004.jpg'])

# %%
IMG_IDS = [p.split('\\')[-1][:-4] for p in IMG_NAMES_FULL]
len(IMG_IDS), IMG_IDS[:5]
# Out:
# (1491, ['90000', '90001', '90002', '90003', '90004'])

# %%
imgid_to_index = {imgid: ii for ii, imgid in enumerate(IMG_IDS)}
imgid_to_index
# Out:
# {'90000': 0,
#  '90001': 1,
#  '90002': 2,
#  '90003': 3,
#  '90004': 4,
#  '90005': 5,
#  '90006': 6,
#  '90007': 7,
#  '90008': 8,
#  '90009': 9,
#  '90010': 10,
#  '90011': 11,
#  '90012': 12,
#  '90013': 13,
#  '90014': 14,
#  '90015': 15,
#  '90016': 16,
#  '90017': 17,
#  '90018': 18,
#  '90019': 19,
#  '90020': 20,
#  '90021': 21,
#  '90022': 22,
#  '90023': 23,
#  '90024': 24,
#  '90025': 25,
#  '90026': 26,
#  '90027': 27,
#  '90028': 28,
#  '90029': 29,
#  '90030': 30,
#  '90031': 31,
#  '90032': 32,
#  '90033': 33,
#  '90034': 34,
#  '90035': 35,
#  '90036': 36,
#  '90037': 37,
#  '90038': 38,
#  '90039': 39,
#  '90040': 40,
#  '90041': 41,
#  '90042': 42,
#  '90043': 43,
#  '90044': 44,
#  '90045': 45,
#  '90046': 46,
#  '90047': 47,
#  '90048': 48,
#  '90049': 49,
#  '90050': 50,
#  '90051': 51,
#  '90052': 52,
#  '90053': 53,
#  '90054': 54,
#  '90055': 55,
#  '90056': 56,
#  '90057': 57,
#  '90058': 58,
#  '90059': 59,
#  '90060': 60,
#  '90061': 61,
#  '90062': 62,
#  '90063': 63,
#  '90064': 64,
#  '90065': 65,
#  '90066': 66,
#  '90067': 67,
#  '90068': 68,
#  '90069': 69,
#  '90070': 70,
#  '90071': 71,
#  '90072': 72,
#  '90073': 73,
#  '90074': 74,
#  '90075': 75,
#  '90076': 76,
#  '90077': 77,
#  '90078': 78,
#  '90079': 79,
# # 1. Sample some descriptors for codebook learning
# Because RAM is not that cheap, loading all descriptors in RAM and fit a k-Means on them usually is impossible.
# We will select some image and load the descriptors for those images.

# %% [markdown]
# ### 1.1 Load descriptors

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Randomly select 100 siftgeo files and load the descriptors from them. We will call those descriptors `train_desc`.**
# </div>

# %%
# TODO sample some images
# sample_image_ids = np.random.choice(...)
# sample_images = ...
n = len(IMG_IDS)
sample_image_ids = np.random.choice(n, size=100, replace=False)
sample_images = []
for ids in sample_image_ids:
    sample_images.append(siftgeo_read_full(IMG_NAMES_FULL[ids]))

# %%
# TODO load (all) the descriptors for those images
# train_desc = []
# for imid in sample_images:
#     ...
# len(train_desc)

train_desc = []
for imid in sample_image_ids:
    train_desc.append(siftgeo_read_desc(PATH_TO_RESOURCES + '\\siftgeo\\' + IMG_IDS[imid] + '.siftgeo'))

# %% [markdown]
# ### 1.2 Prepare those descriptors for training
# For those descriptors to be helpful, we need them to be staked in a big single array of shape `(num_desc, desc_len)` where `desc_len` is the length of a single descriptor — here 128 because SIFT decriptors are vectors of 128 integers.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Turn your list of arrays of descriptors in a big single array. Its shape should be something like `(314302, 128)`.**
#
# Hint: look as `numpy.*stack` functions.
# </div>

# %%
# TODO stack all you descriptors into one big array
# train_desc = ... # FIXME
# train_desc.shape, train_desc.dtype
train_desc = np.concatenate(train_desc)
train_desc.shape, train_desc.dtype
# Out:
# ((281085, 128), dtype('uint8'))

# %% [markdown]
# Finally, we convert this array to float32 elements to avoid normalization issues.

# %%
train_desc = train_desc.astype(np.float32)

# %% [markdown]
# ## 2. Learn normalisation parameters for descriptors
# Before learning a codebook, it is a good practice to:
# - center the features;
# - reduce their dimension using PCA.
#
# **Warning**: We do NOT REDUCE (divide by the variance) the descriptors here because we want to keep the relative value of the variables. This is indeed the very purpose of histograms!
#
# **This is a first learning step!** Because we will compute a **mean** and **eigenvectors** on a **training set**, we need to **store those values** in order to be able to apply them to test elements later.

# %% [markdown]
# ### 2.1 Centering descriptors

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Compute and store the mean of your descriptors, then center them.**
# </div>

# %%
# TODO compute mean and center descriptors
# train_mean = ...
# train_desc = ...
train_mean = np.mean(train_desc, axis=0)
train_desc = train_desc - train_mean

# %% [markdown]
# ### 2.2 PCA
# We will now compute the PCA parameters which will allow us to reduce the dimension of our descriptors from 128 floats to 64 floats, keeping as much information as possible.

# %%
# compute PCA matrix and keep only 64 dimensions
train_cov = np.dot(train_desc.T, train_desc)
eigvals, eigvecs = np.linalg.eig(train_cov)
perm = eigvals.argsort()                   # sort by increasing eigenvalue
pca_transform = eigvecs[:, perm[64:128]]   # eigenvectors for the 64 last eigenvalues
pca_transform.shape, pca_transform.dtype
# Out:
# ((128, 64), dtype('float32'))

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Apply the PCA transformation to your descriptors.**
#
# Hint: we expect to get a new `train_desc` array with the same number of rows, but only 64 columns (dimensions).
# </div>

# %%
# TODO
# perform the appropriate matrix multiplication to transform your descriptors
# train_desc = ...
train_desc = np.dot(train_desc, pca_transform)

# %%
# Check the shape of your new descriptors: we expect a shape like (BIGNUMBER, 64)
train_desc.shape
# Out:
# (281085, 64)

# %% [markdown]
# ## 3. Use k-Means to learn a codebook
# We are now ready to learn a codebook using those centered and compact descriptors.
# We will use exactly the same technique as the one we used to compute color histograms:
# - first we fit a k-Means;
# - then, using the centroids we found, we will project the descriptors and compute bag of features for each image.

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Fit a k-Means with 512 clusters on the training descriptors.**
# </div>

# %%
# TODO fit a k-means (this can take some time; approx. 2 minutes on an 8-cores laptop)
# kmeans = ...
kmeans = MiniBatchKMeans(n_clusters=512)
kmeans.fit(train_desc)
# Out:
# C:\Users\subru\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)
# C:\Users\subru\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)
# C:\Users\subru\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=300 should be larger than k=512. Setting it to 3*k
#   init_size=init_size)
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=512, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
# let's check the shape of the cluster's centers
kmeans.cluster_centers_.shape
# Out:
# (512, 64)

# %% [markdown]
# We expect a shape of `(512, 64)` for cluster centers: we have 512 clusters in a 64-dimensional space.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **How do we call this set of cluster centers? They define the set of possible descriptor values we will use to build bag of visual words descriptors. Write down your answer.**
# </div>

# %% [markdown]
# TODO
# We call this set of cluster centers ... codebook

# %% [markdown]
# ## 4. Compute the BoVW vector for each image
# Using the codebook we just learned, we will compute for each image its bag of features vector (histogram of projected descriptors).
#
# It is almost exaclty like the color histogram we computed in practice session 2!
# The **only** difference is that we have much more dimensions.
#
# We will put those descriptors in a naive index made of a single NumPy array.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **For each image, compute its BoVW vector.**
# </div>
#
# **Beware:**
# - in a few images no descriptor was extracted so you need to skip those elements
# - you need to apply the same preprocessings than the ones you applied to training descriptors (center, dimension reduction)

# %%
# TODO index all images

# Here is our very simple index (keep it initialized like this)
global_image_descr = np.zeros((len(IMG_IDS), kmeans.n_clusters), dtype=np.float32)

for ii, imgid in enumerate(IMG_IDS):
    print("Indexing %s" % (imgid,))
    # read the descriptors
    # desc = ...  # FIXME
    desc = siftgeo_read_desc(PATH_TO_RESOURCES + '/siftgeo/' + imgid + '.siftgeo')
    
    # handle case where no descriptor is available
    if desc.shape[0] == 0:
        # let the descriptor be 0 for all values
        # note that this is bad and the element should be dropped from the index
        # but here we keep it to preserve image vs desc ids (no worries, it will work)
        print("WARNING: zero descriptor for %s" % (imgid,))
        continue
    
    # apply the same preprocessing as for training descriptors
    # ...   # FIXME
    desc = np.dot((desc-train_mean), pca_transform)

    # get cluster ids
    # ...  # FIXME
    c_ids = kmeans.predict(desc)
    
    # compute histogram (do not forget to normalize by the number of descriptors)
    # descr_hist = ...  # FIXME
    descr_hist = np.bincount(c_ids, minlength=512)
    descr_hist = descr_hist / np.sum(descr_hist)
    
    # update the index
    # global_image_descr[ii] = descr_hist   # FIXME (just uncomment)
    global_image_descr[ii] = descr_hist
print("Indexing complete.")
global_image_descr.shape, global_image_descr.dtype
# Out:
# Indexing 90000
# Indexing 90001
# Indexing 90002
# Indexing 90003
# Indexing 90004
# Indexing 90005
# Indexing 90006
# Indexing 90007
# Indexing 90008
# Indexing 90009
# Indexing 90010
# Indexing 90011
# Indexing 90012
# Indexing 90013
# Indexing 90014
# Indexing 90015
# Indexing 90016
# Indexing 90017
# Indexing 90018
# Indexing 90019
# Indexing 90020
# Indexing 90021
# Indexing 90022
# Indexing 90023
# Indexing 90024
# Indexing 90025
# Indexing 90026
# Indexing 90027
# Indexing 90028
# Indexing 90029
# Indexing 90030
# Indexing 90031
# Indexing 90032
# Indexing 90033
# Indexing 90034
# Indexing 90035
# Indexing 90036
# Indexing 90037
# Indexing 90038
# Indexing 90039
# Indexing 90040
# Indexing 90041
# Indexing 90042
# Indexing 90043
# Indexing 90044
# Indexing 90045
# Indexing 90046
# Indexing 90047
# Indexing 90048
# Indexing 90049
# Indexing 90050
# Indexing 90051
# Indexing 90052
# Indexing 90053
# Indexing 90054
# Indexing 90055
# Indexing 90056
# Indexing 90057
# Indexing 90058
# Indexing 90059
# Indexing 90060
# Indexing 90061
# Indexing 90062
# Indexing 90063
# Indexing 90064
# Indexing 90065
# Indexing 90066
# Indexing 90067
# Indexing 90068
# Indexing 90069
# Indexing 90070
# Indexing 90071
# Indexing 90072
# Indexing 90073
# Indexing 90074
# Indexing 90075
# Indexing 90076
# Indexing 90077
# Indexing 90078
# Indexing 90079
# Indexing 90080
# Indexing 90081
# Indexing 90082
# Indexing 90083
# Indexing 90084
# Indexing 90085
# Indexing 90086
# Indexing 90087
# Indexing 90088
# Indexing 90089
# Indexing 90090
# Indexing 90091
# Indexing 90092
# Indexing 90093
# Indexing 90094
# Indexing 90095
# Indexing 90096
# Indexing 90097
# Indexing 90098
# Indexing 90099
# Indexing 90100
# Indexing 90101
# Indexing 90102
# Indexing 90103
# Indexing 90104
# Indexing 90105
# Indexing 90106
# Indexing 90107
# Indexing 90108
# Indexing 90109
# Indexing 90110
# Indexing 90111
# Indexing 90112
# Indexing 90113
# Indexing 90114
# Indexing 90115
# Indexing 90116
# Indexing 90117
# Indexing 90118
# Indexing 90119
# Indexing 90120
# Indexing 90121
# Indexing 90122
# Indexing 90123
# Indexing 90124
# Indexing 90125
# Indexing 90126
# Indexing 90127
# Indexing 90128
# Indexing 90129
# Indexing 90130
# Indexing 90131
# Indexing 90132
# Indexing 90133
# Indexing 90134
# Indexing 90135
# Indexing 90136
# Indexing 90137
# Indexing 90138
# Indexing 90139
# Indexing 90140
# Indexing 90141
# Indexing 90142
# Indexing 90143
# Indexing 90144
# Indexing 90145
# Indexing 90146
# Indexing 90147
# Indexing 90148
# Indexing 90149
# Indexing 90150
# Indexing 90151
# Indexing 90152
# Indexing 90153
# Indexing 90154
# Indexing 90155
# Indexing 90156
# Indexing 90157
# Indexing 90158
# Indexing 90159
# Indexing 90160
# Indexing 90161
# Indexing 90162
# Indexing 90163
# Indexing 90164
# Indexing 90165
# Indexing 90166
# Indexing 90167
# Indexing 90168
# Indexing 90169
# WARNING: zero descriptor for 90169
# Indexing 90170
# Indexing 90171
# Indexing 90172
# Indexing 90173
# Indexing 90174
# Indexing 90175
# Indexing 90176
# Indexing 90177
# Indexing 90178
# Indexing 90179
# Indexing 90180
# Indexing 90181
# Indexing 90182
# Indexing 90183
# Indexing 90184
# Indexing 90185
# Indexing 90186
# Indexing 90187
# Indexing 90188
# Indexing 90189
# Indexing 90190
# Indexing 90191
# Indexing 90192
# Indexing 90193
# Indexing 90194
# Indexing 90195
# Indexing 90196
# Indexing 90197
# Indexing 90198
# Indexing 90199
# Indexing 90200
# Indexing 90201
# Indexing 90202
# Indexing 90203
# Indexing 90204
# Indexing 90205
# Indexing 90206
# Indexing 90207
# Indexing 90208
# Indexing 90209
# Indexing 90210
# Indexing 90211
# Indexing 90212
# Indexing 90213
# Indexing 90214
# Indexing 90215
# Indexing 90216
# Indexing 90217
# Indexing 90218
# Indexing 90219
# Indexing 90220
# Indexing 90221
# Indexing 90222
# Indexing 90223
# Indexing 90224
# Indexing 90225
# Indexing 90226
# Indexing 90227
# Indexing 90228
# Indexing 90229
# Indexing 90230
# Indexing 90231
# Indexing 90232
# Indexing 90233
# Indexing 90234
# Indexing 90235
# Indexing 90236
# Indexing 90237
# Indexing 90238
# Indexing 90239
# Indexing 90240
# Indexing 90241
# Indexing 90242
# Indexing 90243
# Indexing 90244
# Indexing 90245
# Indexing 90246
# Indexing 90247
# Indexing 90248
# Indexing 90249
# Indexing 90250
# Indexing 90251
# Indexing 90252
# Indexing 90253
# Indexing 90254
# Indexing 90255
# Indexing 90256
# Indexing 90257
# Indexing 90258
# Indexing 90259
# Indexing 90260
# Indexing 90261
# Indexing 90262
# Indexing 90263
# Indexing 90264
# Indexing 90265
# Indexing 90266
# Indexing 90267
# Indexing 90268
# Indexing 90269
# Indexing 90270
# Indexing 90271
# Indexing 90272
# Indexing 90273
# Indexing 90274
# Indexing 90275
# Indexing 90276
# Indexing 90277
# Indexing 90278
# Indexing 90279
# Indexing 90280
# Indexing 90281
# Indexing 90282
# Indexing 90283
# Indexing 90284
# Indexing 90285
# Indexing 90286
# Indexing 90287
# Indexing 90288
# Indexing 90289
# Indexing 90290
# Indexing 90291
# Indexing 90292
# Indexing 90293
# Indexing 90294
# Indexing 90295
# Indexing 90296
# Indexing 90297
# Indexing 90298
# Indexing 90299
# Indexing 90300
# Indexing 90301
# Indexing 90302
# Indexing 90303
# Indexing 90304
# Indexing 90305
# Indexing 90306
# Indexing 90307
# Indexing 90308
# Indexing 90309
# Indexing 90310
# Indexing 90311
# Indexing 90312
# Indexing 90313
# Indexing 90314
# Indexing 90315
# Indexing 90316
# Indexing 90317
# Indexing 90318
# Indexing 90319
# Indexing 90320
# Indexing 90321
# Indexing 90322
# Indexing 90323
# Indexing 90324
# Indexing 90325
# Indexing 90326
# Indexing 90327
# Indexing 90328
# Indexing 90329
# Indexing 90330
# Indexing 90331
# Indexing 90332
# Indexing 90333
# Indexing 90334
# Indexing 90335
# Indexing 90336
# Indexing 90337
# Indexing 90338
# Indexing 90339
# Indexing 90340
# Indexing 90341
# Indexing 90342
# Indexing 90343
# Indexing 90344
# Indexing 90345
# Indexing 90346
# Indexing 90347
# Indexing 90348
# Indexing 90349
# Indexing 90350
# Indexing 90351
# Indexing 90352
# Indexing 90353
# Indexing 90354
# Indexing 90355
# Indexing 90356
# Indexing 90357
# Indexing 90358
# Indexing 90359
# Indexing 90360
# Indexing 90361
# Indexing 90362
# Indexing 90363
# Indexing 90364
# Indexing 90365
# Indexing 90366
# Indexing 90367
# Indexing 90368
# Indexing 90369
# Indexing 90370
# Indexing 90371
# Indexing 90372
# Indexing 90373
# Indexing 90374
# Indexing 90375
# Indexing 90376
# Indexing 90377
# Indexing 90378
# Indexing 90379
# Indexing 90380
# Indexing 90381
# Indexing 90382
# Indexing 90383
# Indexing 90384
# Indexing 90385
# Indexing 90386
# Indexing 90387
# Indexing 90388
# Indexing 90389
# Indexing 90390
# Indexing 90391
# Indexing 90392
# Indexing 90393
# Indexing 90394
# Indexing 90395
# Indexing 90396
# Indexing 90397
# Indexing 90398
# Indexing 90399
# Indexing 90400
# Indexing 90401
# Indexing 90402
# Indexing 90403
# Indexing 90404
# Indexing 90405
# Indexing 90406
# Indexing 90407
# Indexing 90408
# Indexing 90409
# Indexing 90410
# Indexing 90411
# Indexing 90412
# Indexing 90413
# Indexing 90414
# Indexing 90415
# Indexing 90416
# Indexing 90417
# Indexing 90418
# Indexing 90419
# Indexing 90420
# Indexing 90421
# Indexing 90422
# Indexing 90423
# Indexing 90424
# Indexing 90425
# Indexing 90426
# Indexing 90427
# Indexing 90428
# Indexing 90429
# Indexing 90430
# Indexing 90431
# Indexing 90432
# Indexing 90433
# Indexing 90434
# Indexing 90435
# Indexing 90436
# Indexing 90437
# Indexing 90438
# Indexing 90439
# Indexing 90440
# Indexing 90441
# Indexing 90442
# Indexing 90443
# Indexing 90444
# Indexing 90445
# Indexing 90446
# Indexing 90447
# Indexing 90448
# Indexing 90449
# Indexing 90450
# Indexing 90451
# Indexing 90452
# Indexing 90453
# Indexing 90454
# Indexing 90455
# Indexing 90456
# Indexing 90457
# Indexing 90458
# Indexing 90459
# Indexing 90460
# Indexing 90461
# Indexing 90462
# Indexing 90463
# Indexing 90464
# Indexing 90465
# Indexing 90466
# Indexing 90467
# Indexing 90468
# Indexing 90469
# Indexing 90470
# Indexing 90471
# Indexing 90472
# Indexing 90473
# Indexing 90474
# Indexing 90475
# Indexing 90476
# Indexing 90477
# Indexing 90478
# Indexing 90479
# Indexing 90480
# Indexing 90481
# Indexing 90482
# Indexing 90483
# Indexing 90484
# Indexing 90485
# Indexing 90486
# Indexing 90487
# Indexing 90488
# Indexing 90489
# Indexing 90490
# Indexing 90491
# Indexing 90492
# Indexing 90493
# Indexing 90494
# Indexing 90495
# Indexing 90496
# Indexing 90497
# Indexing 90498
# Indexing 90499
# Indexing 90500
# Indexing 90501
# Indexing 90502
# Indexing 90503
# Indexing 90504
# Indexing 90505
# Indexing 90506
# Indexing 90507
# Indexing 90508
# Indexing 90509
# Indexing 90510
# Indexing 90511
# Indexing 90512
# Indexing 90513
# Indexing 90514
# Indexing 90515
# Indexing 90516
# Indexing 90517
# Indexing 90518
# Indexing 90519
# Indexing 90520
# Indexing 90521
# Indexing 90522
# Indexing 90523
# Indexing 90524
# Indexing 90525
# Indexing 90526
# Indexing 90527
# Indexing 90528
# Indexing 90529
# Indexing 90530
# Indexing 90531
# Indexing 90532
# Indexing 90533
# Indexing 90534
# Indexing 90535
# Indexing 90536
# Indexing 90537
# Indexing 90538
# Indexing 90539
# Indexing 90540
# Indexing 90541
# Indexing 90542
# Indexing 90543
# Indexing 90544
# Indexing 90545
# Indexing 90546
# Indexing 90547
# Indexing 90548
# Indexing 90549
# Indexing 90550
# Indexing 90551
# Indexing 90552
# Indexing 90553
# Indexing 90554
# Indexing 90555
# Indexing 90556
# Indexing 90557
# Indexing 90558
# Indexing 90559
# Indexing 90560
# Indexing 90561
# Indexing 90562
# Indexing 90563
# Indexing 90564
# Indexing 90565
# Indexing 90566
# Indexing 90567
# Indexing 90568
# Indexing 90569
# Indexing 90570
# Indexing 90571
# Indexing 90572
# Indexing 90573
# Indexing 90574
# Indexing 90575
# Indexing 90576
# Indexing 90577
# Indexing 90578
# Indexing 90579
# Indexing 90580
# Indexing 90581
# Indexing 90582
# Indexing 90583
# Indexing 90584
# Indexing 90585
# Indexing 90586
# Indexing 90587
# Indexing 90588
# Indexing 90589
# Indexing 90590
# Indexing 90591
# Indexing 90592
# Indexing 90593
# Indexing 90594
# Indexing 90595
# Indexing 90596
# Indexing 90597
# Indexing 90598
# Indexing 90599
# Indexing 90600
# Indexing 90601
# Indexing 90602
# Indexing 90603
# Indexing 90604
# Indexing 90605
# Indexing 90606
# Indexing 90607
# Indexing 90608
# Indexing 90609
# Indexing 90610
# Indexing 90611
# Indexing 90612
# Indexing 90613
# Indexing 90614
# Indexing 90615
# Indexing 90616
# Indexing 90617
# Indexing 90618
# Indexing 90619
# Indexing 90620
# Indexing 90621
# Indexing 90622
# Indexing 90623
# Indexing 90624
# Indexing 90625
# Indexing 90626
# Indexing 90627
# Indexing 90628
# Indexing 90629
# Indexing 90630
# Indexing 90631
# Indexing 90632
# Indexing 90633
# Indexing 90634
# Indexing 90635
# Indexing 90636
# Indexing 90637
# Indexing 90638
# Indexing 90639
# Indexing 90640
# Indexing 90641
# Indexing 90642
# Indexing 90643
# Indexing 90644
# Indexing 90645
# Indexing 90646
# Indexing 90647
# Indexing 90648
# Indexing 90649
# Indexing 90650
# Indexing 90651
# Indexing 90652
# Indexing 90653
# Indexing 90654
# Indexing 90655
# Indexing 90656
# Indexing 90657
# Indexing 90658
# Indexing 90659
# Indexing 90660
# Indexing 90661
# Indexing 90662
# Indexing 90663
# Indexing 90664
# Indexing 90665
# Indexing 90666
# Indexing 90667
# Indexing 90668
# Indexing 90669
# Indexing 90670
# Indexing 90671
# Indexing 90672
# Indexing 90673
# Indexing 90674
# Indexing 90675
# Indexing 90676
# Indexing 90677
# Indexing 90678
# Indexing 90679
# Indexing 90680
# Indexing 90681
# Indexing 90682
# Indexing 90683
# Indexing 90684
# Indexing 90685
# Indexing 90686
# Indexing 90687
# Indexing 90688
# Indexing 90689
# Indexing 90690
# Indexing 90691
# Indexing 90692
# Indexing 90693
# Indexing 90694
# Indexing 90695
# Indexing 90696
# Indexing 90697
# Indexing 90698
# Indexing 90699
# Indexing 90700
# Indexing 90701
# Indexing 90702
# Indexing 90703
# Indexing 90704
# Indexing 90705
# Indexing 90706
# Indexing 90707
# Indexing 90708
# Indexing 90709
# Indexing 90710
# Indexing 90711
# Indexing 90712
# Indexing 90713
# Indexing 90714
# Indexing 90715
# Indexing 90716
# Indexing 90717
# Indexing 90718
# Indexing 90719
# Indexing 90720
# Indexing 90721
# Indexing 90722
# Indexing 90723
# Indexing 90724
# Indexing 90725
# Indexing 90726
# Indexing 90727
# WARNING: zero descriptor for 90727
# Indexing 90728
# Indexing 90729
# Indexing 90730
# Indexing 90731
# Indexing 90732
# Indexing 90733
# Indexing 90734
# Indexing 90735
# Indexing 90736
# Indexing 90737
# Indexing 90738
# Indexing 90739
# Indexing 90740
# Indexing 90741
# Indexing 90742
# Indexing 90743
# Indexing 90744
# Indexing 90745
# Indexing 90746
# Indexing 90747
# Indexing 90748
# Indexing 90749
# Indexing 90750
# Indexing 90751
# Indexing 90752
# Indexing 90753
# Indexing 90754
# Indexing 90755
# Indexing 90756
# Indexing 90757
# Indexing 90758
# Indexing 90759
# Indexing 90760
# Indexing 90761
# Indexing 90762
# Indexing 90763
# Indexing 90764
# Indexing 90765
# Indexing 90766
# Indexing 90767
# Indexing 90768
# Indexing 90769
# Indexing 90770
# Indexing 90771
# Indexing 90772
# Indexing 90773
# Indexing 90774
# Indexing 90775
# Indexing 90776
# Indexing 90777
# Indexing 90778
# Indexing 90779
# Indexing 90780
# Indexing 90781
# Indexing 90782
# Indexing 90783
# Indexing 90784
# Indexing 90785
# Indexing 90786
# Indexing 90787
# Indexing 90788
# Indexing 90789
# Indexing 90790
# Indexing 90791
# Indexing 90792
# Indexing 90793
# Indexing 90794
# Indexing 90795
# Indexing 90796
# Indexing 90797
# Indexing 90798
# Indexing 90799
# Indexing 90800
# Indexing 90801
# Indexing 90802
# Indexing 90803
# Indexing 90804
# Indexing 90805
# Indexing 90806
# Indexing 90807
# Indexing 90808
# Indexing 90809
# Indexing 90810
# Indexing 90811
# Indexing 90812
# Indexing 90813
# Indexing 90814
# Indexing 90815
# Indexing 90816
# Indexing 90817
# Indexing 90818
# Indexing 90819
# Indexing 90820
# Indexing 90821
# Indexing 90822
# Indexing 90823
# Indexing 90824
# Indexing 90825
# Indexing 90826
# Indexing 90827
# Indexing 90828
# Indexing 90829
# Indexing 90830
# Indexing 90831
# Indexing 90832
# Indexing 90833
# Indexing 90834
# Indexing 90835
# Indexing 90836
# Indexing 90837
# Indexing 90838
# Indexing 90839
# Indexing 90840
# Indexing 90841
# Indexing 90842
# Indexing 90843
# Indexing 90844
# Indexing 90845
# Indexing 90846
# Indexing 90847
# Indexing 90848
# Indexing 90849
# Indexing 90850
# Indexing 90851
# Indexing 90852
# Indexing 90853
# Indexing 90854
# Indexing 90855
# Indexing 90856
# Indexing 90857
# Indexing 90858
# Indexing 90859
# Indexing 90860
# Indexing 90861
# Indexing 90862
# Indexing 90863
# Indexing 90864
# Indexing 90865
# Indexing 90866
# Indexing 90867
# Indexing 90868
# Indexing 90869
# Indexing 90870
# Indexing 90871
# Indexing 90872
# Indexing 90873
# Indexing 90874
# Indexing 90875
# Indexing 90876
# Indexing 90877
# Indexing 90878
# Indexing 90879
# Indexing 90880
# Indexing 90881
# Indexing 90882
# Indexing 90883
# Indexing 90884
# Indexing 90885
# Indexing 90886
# Indexing 90887
# Indexing 90888
# Indexing 90889
# Indexing 90890
# Indexing 90891
# Indexing 90892
# Indexing 90893
# Indexing 90894
# Indexing 90895
# Indexing 90896
# Indexing 90897
# Indexing 90898
# Indexing 90899
# Indexing 90900
# Indexing 90901
# Indexing 90902
# Indexing 90903
# Indexing 90904
# Indexing 90905
# Indexing 90906
# Indexing 90907
# Indexing 90908
# Indexing 90909
# Indexing 90910
# Indexing 90911
# Indexing 90912
# Indexing 90913
# Indexing 90914
# Indexing 90915
# Indexing 90916
# Indexing 90917
# Indexing 90918
# Indexing 90919
# Indexing 90920
# Indexing 90921
# Indexing 90922
# Indexing 90923
# Indexing 90924
# Indexing 90925
# Indexing 90926
# Indexing 90927
# Indexing 90928
# Indexing 90929
# Indexing 90930
# Indexing 90931
# Indexing 90932
# Indexing 90933
# Indexing 90934
# Indexing 90935
# Indexing 90936
# Indexing 90937
# Indexing 90938
# Indexing 90939
# Indexing 90940
# Indexing 90941
# Indexing 90942
# Indexing 90943
# Indexing 90944
# Indexing 90945
# Indexing 90946
# Indexing 90947
# Indexing 90948
# Indexing 90949
# Indexing 90950
# Indexing 90951
# Indexing 90952
# Indexing 90953
# Indexing 90954
# Indexing 90955
# Indexing 90956
# Indexing 90957
# Indexing 90958
# Indexing 90959
# Indexing 90960
# Indexing 90961
# Indexing 90962
# Indexing 90963
# Indexing 90964
# Indexing 90965
# Indexing 90966
# Indexing 90967
# Indexing 90968
# Indexing 90969
# Indexing 90970
# Indexing 90971
# Indexing 90972
# Indexing 90973
# Indexing 90974
# Indexing 90975
# Indexing 90976
# Indexing 90977
# Indexing 90978
# Indexing 90979
# Indexing 90980
# Indexing 90981
# Indexing 90982
# Indexing 90983
# Indexing 90984
# Indexing 90985
# Indexing 90986
# Indexing 90987
# Indexing 90988
# Indexing 90989
# Indexing 90990
# Indexing 90991
# Indexing 90992
# Indexing 90993
# Indexing 90994
# Indexing 90995
# Indexing 90996
# Indexing 90997
# Indexing 90998
# Indexing 90999
# Indexing 91000
# Indexing 91001
# Indexing 91002
# Indexing 91003
# Indexing 91004
# Indexing 91005
# Indexing 91006
# Indexing 91007
# Indexing 91008
# Indexing 91009
# Indexing 91010
# Indexing 91011
# Indexing 91012
# Indexing 91013
# Indexing 91014
# Indexing 91015
# Indexing 91016
# Indexing 91017
# Indexing 91018
# Indexing 91019
# Indexing 91020
# Indexing 91021
# Indexing 91022
# Indexing 91023
# Indexing 91024
# Indexing 91025
# Indexing 91026
# Indexing 91027
# Indexing 91028
# Indexing 91029
# Indexing 91030
# Indexing 91031
# Indexing 91032
# Indexing 91033
# Indexing 91034
# Indexing 91035
# Indexing 91036
# Indexing 91037
# Indexing 91038
# Indexing 91039
# Indexing 91040
# Indexing 91041
# Indexing 91042
# Indexing 91043
# Indexing 91044
# Indexing 91045
# Indexing 91046
# Indexing 91047
# Indexing 91048
# Indexing 91049
# Indexing 91050
# Indexing 91051
# Indexing 91052
# Indexing 91053
# Indexing 91054
# Indexing 91055
# Indexing 91056
# Indexing 91057
# Indexing 91058
# Indexing 91059
# Indexing 91060
# Indexing 91061
# Indexing 91062
# Indexing 91063
# Indexing 91064
# Indexing 91065
# Indexing 91066
# Indexing 91067
# Indexing 91068
# Indexing 91069
# Indexing 91070
# Indexing 91071
# Indexing 91072
# Indexing 91073
# Indexing 91074
# Indexing 91075
# Indexing 91076
# Indexing 91077
# Indexing 91078
# Indexing 91079
# Indexing 91080
# Indexing 91081
# Indexing 91082
# Indexing 91083
# Indexing 91084
# Indexing 91085
# Indexing 91086
# Indexing 91087
# Indexing 91088
# Indexing 91089
# Indexing 91090
# Indexing 91091
# Indexing 91092
# Indexing 91093
# Indexing 91094
# Indexing 91095
# Indexing 91096
# Indexing 91097
# Indexing 91098
# Indexing 91099
# Indexing 91100
# Indexing 91101
# Indexing 91102
# Indexing 91103
# Indexing 91104
# Indexing 91105
# Indexing 91106
# Indexing 91107
# Indexing 91108
# Indexing 91109
# Indexing 91110
# Indexing 91111
# Indexing 91112
# Indexing 91113
# Indexing 91114
# Indexing 91115
# Indexing 91116
# Indexing 91117
# Indexing 91118
# Indexing 91119
# Indexing 91120
# Indexing 91121
# Indexing 91122
# Indexing 91123
# Indexing 91124
# Indexing 91125
# Indexing 91126
# Indexing 91127
# Indexing 91128
# Indexing 91129
# Indexing 91130
# Indexing 91131
# Indexing 91132
# Indexing 91133
# Indexing 91134
# Indexing 91135
# Indexing 91136
# Indexing 91137
# Indexing 91138
# Indexing 91139
# Indexing 91140
# Indexing 91141
# Indexing 91142
# Indexing 91143
# Indexing 91144
# Indexing 91145
# Indexing 91146
# Indexing 91147
# Indexing 91148
# Indexing 91149
# Indexing 91150
# Indexing 91151
# Indexing 91152
# Indexing 91153
# Indexing 91154
# Indexing 91155
# Indexing 91156
# Indexing 91157
# Indexing 91158
# Indexing 91159
# Indexing 91160
# Indexing 91161
# Indexing 91162
# Indexing 91163
# Indexing 91164
# Indexing 91165
# Indexing 91166
# Indexing 91167
# Indexing 91168
# Indexing 91169
# Indexing 91170
# Indexing 91171
# Indexing 91172
# Indexing 91173
# Indexing 91174
# Indexing 91175
# Indexing 91176
# Indexing 91177
# Indexing 91178
# Indexing 91179
# Indexing 91180
# Indexing 91181
# Indexing 91182
# Indexing 91183
# Indexing 91184
# Indexing 91185
# Indexing 91186
# Indexing 91187
# Indexing 91188
# Indexing 91189
# Indexing 91190
# Indexing 91191
# Indexing 91192
# Indexing 91193
# Indexing 91194
# Indexing 91195
# Indexing 91196
# Indexing 91197
# Indexing 91198
# Indexing 91199
# Indexing 91200
# Indexing 91201
# Indexing 91202
# Indexing 91203
# Indexing 91204
# Indexing 91205
# Indexing 91206
# Indexing 91207
# Indexing 91208
# Indexing 91209
# Indexing 91210
# Indexing 91211
# Indexing 91212
# Indexing 91213
# Indexing 91214
# Indexing 91215
# Indexing 91216
# Indexing 91217
# Indexing 91218
# Indexing 91219
# Indexing 91220
# Indexing 91221
# Indexing 91222
# Indexing 91223
# Indexing 91224
# Indexing 91225
# Indexing 91226
# Indexing 91227
# Indexing 91228
# Indexing 91229
# Indexing 91230
# Indexing 91231
# Indexing 91232
# Indexing 91233
# Indexing 91234
# Indexing 91235
# Indexing 91236
# Indexing 91237
# Indexing 91238
# Indexing 91239
# Indexing 91240
# Indexing 91241
# Indexing 91242
# Indexing 91243
# Indexing 91244
# Indexing 91245
# Indexing 91246
# Indexing 91247
# Indexing 91248
# Indexing 91249
# Indexing 91250
# Indexing 91251
# Indexing 91252
# Indexing 91253
# Indexing 91254
# Indexing 91255
# Indexing 91256
# Indexing 91257
# Indexing 91258
# Indexing 91259
# Indexing 91260
# Indexing 91261
# Indexing 91262
# Indexing 91263
# Indexing 91264
# Indexing 91265
# Indexing 91266
# Indexing 91267
# Indexing 91268
# Indexing 91269
# Indexing 91270
# Indexing 91271
# Indexing 91272
# Indexing 91273
# Indexing 91274
# Indexing 91275
# Indexing 91276
# Indexing 91277
# Indexing 91278
# Indexing 91279
# Indexing 91280
# WARNING: zero descriptor for 91280
# Indexing 91281
# Indexing 91282
# Indexing 91283
# Indexing 91284
# Indexing 91285
# Indexing 91286
# Indexing 91287
# Indexing 91288
# Indexing 91289
# Indexing 91290
# Indexing 91291
# Indexing 91292
# Indexing 91293
# Indexing 91294
# Indexing 91295
# Indexing 91296
# Indexing 91297
# Indexing 91298
# Indexing 91299
# Indexing 91300
# Indexing 91301
# Indexing 91302
# Indexing 91303
# Indexing 91304
# Indexing 91305
# Indexing 91306
# Indexing 91307
# Indexing 91308
# Indexing 91309
# Indexing 91310
# Indexing 91311
# Indexing 91312
# Indexing 91313
# Indexing 91314
# Indexing 91315
# Indexing 91316
# Indexing 91317
# Indexing 91318
# Indexing 91319
# Indexing 91320
# Indexing 91321
# Indexing 91322
# Indexing 91323
# Indexing 91324
# Indexing 91325
# Indexing 91326
# Indexing 91327
# Indexing 91328
# Indexing 91329
# Indexing 91330
# Indexing 91331
# Indexing 91332
# Indexing 91333
# Indexing 91334
# Indexing 91335
# Indexing 91336
# Indexing 91337
# Indexing 91338
# Indexing 91339
# Indexing 91340
# Indexing 91341
# Indexing 91342
# Indexing 91343
# Indexing 91344
# Indexing 91345
# Indexing 91346
# Indexing 91347
# Indexing 91348
# Indexing 91349
# Indexing 91350
# Indexing 91351
# Indexing 91352
# Indexing 91353
# Indexing 91354
# Indexing 91355
# Indexing 91356
# Indexing 91357
# Indexing 91358
# Indexing 91359
# Indexing 91360
# Indexing 91361
# Indexing 91362
# Indexing 91363
# Indexing 91364
# Indexing 91365
# Indexing 91366
# Indexing 91367
# Indexing 91368
# Indexing 91369
# Indexing 91370
# Indexing 91371
# Indexing 91372
# Indexing 91373
# Indexing 91374
# Indexing 91375
# Indexing 91376
# Indexing 91377
# Indexing 91378
# Indexing 91379
# Indexing 91380
# Indexing 91381
# Indexing 91382
# Indexing 91383
# Indexing 91384
# Indexing 91385
# Indexing 91386
# Indexing 91387
# Indexing 91388
# Indexing 91389
# Indexing 91390
# Indexing 91391
# Indexing 91392
# Indexing 91393
# Indexing 91394
# Indexing 91395
# Indexing 91396
# Indexing 91397
# Indexing 91398
# Indexing 91399
# Indexing 91400
# Indexing 91401
# Indexing 91402
# Indexing 91403
# Indexing 91404
# Indexing 91405
# Indexing 91406
# Indexing 91407
# Indexing 91408
# Indexing 91409
# Indexing 91410
# Indexing 91411
# Indexing 91412
# Indexing 91413
# Indexing 91414
# Indexing 91415
# Indexing 91416
# Indexing 91417
# Indexing 91418
# Indexing 91419
# Indexing 91420
# Indexing 91421
# Indexing 91422
# Indexing 91423
# Indexing 91424
# Indexing 91425
# Indexing 91426
# Indexing 91427
# Indexing 91428
# Indexing 91429
# Indexing 91430
# Indexing 91431
# Indexing 91432
# Indexing 91433
# Indexing 91434
# Indexing 91435
# Indexing 91436
# Indexing 91437
# Indexing 91438
# Indexing 91439
# Indexing 91440
# Indexing 91441
# Indexing 91442
# Indexing 91443
# Indexing 91444
# Indexing 91445
# Indexing 91446
# Indexing 91447
# Indexing 91448
# Indexing 91449
# Indexing 91450
# Indexing 91451
# Indexing 91452
# Indexing 91453
# Indexing 91454
# Indexing 91455
# Indexing 91456
# Indexing 91457
# Indexing 91458
# Indexing 91459
# Indexing 91460
# Indexing 91461
# Indexing 91462
# Indexing 91463
# Indexing 91464
# Indexing 91465
# Indexing 91466
# Indexing 91467
# Indexing 91468
# Indexing 91469
# Indexing 91470
# Indexing 91471
# Indexing 91472
# Indexing 91473
# Indexing 91474
# Indexing 91475
# Indexing 91476
# Indexing 91477
# Indexing 91478
# Indexing 91479
# Indexing 91480
# Indexing 91481
# Indexing 91482
# Indexing 91483
# Indexing 91484
# Indexing 91485
# Indexing 91486
# Indexing 91487
# Indexing 91488
# Indexing 91489
# Indexing 91490
# Indexing complete.
# ((1491, 512), dtype('float32'))

# %% [markdown]
# ## 5. Setup a nearest neighbors search structure
# We will use a simple nearest neighbors implementation to test our approach.

# %%
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Using scikit-learn's implementation of nearest neighbors, setup a search engine with a linear search strategy and an appropriate metric.**
# </div>

# %%
# TODO setup search engine
# search_engine = NearestNeighbors(algorithm=???, metric=???)
search_engine = NearestNeighbors(algorithm='brute', metric='cosine')

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Now index you descriptors.**
# </div>

# %%
# TODO index descriptors
# search_engine. ...
search_engine.fit(global_image_descr)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %% [markdown]
# ## 6. Evaluate our approach using mean average precision
# We can now evaluate the performance of our search engine using the available ground truth.
#
# ### 6.1 Load the ground truth
# The ground truth is a simple dictionary mapping query ids to relevant image ids:
# ```json
# {'90314': ['90989', '91259'],
#  '90376': ['90674'],
#  '90175': ['90512'],
#  ...
# }
# ```

# %%
import json
PATH_TO_GT = os.path.join(PATH_TO_RESOURCES, "gt_student.json")
gt_data = None
with open(PATH_TO_GT, 'r') as in_gt:
    gt_data = json.load(in_gt)

# %% [markdown]
# ### 6.3 Select the descriptors of the query images
#
# The annoying part is to convert between the indices of the elements in our index structure `global_image_descr` and the images ids which allow us to find files.
#
# The upside is that reusing the precomputed descriptors avoids us the need for computing the BoVW vector for each query image.
#
# We use the `imgid_to_index`, which helps us converting between image ids (filename without directory nor extension) and index value in the `global_image_descr` array, to recover the indices of the rows corresponding to the query images in `global_image_descr`.
#
# Here is below some code you should run and try to understand.

# %%
# get the indices of the query images
query_imnos = [imgid_to_index[query_id] for query_id in gt_data.keys()]

# %%
imgid_to_index
# Out:
# {'90000': 0,
#  '90001': 1,
#  '90002': 2,
#  '90003': 3,
#  '90004': 4,
#  '90005': 5,
#  '90006': 6,
#  '90007': 7,
#  '90008': 8,
#  '90009': 9,
#  '90010': 10,
#  '90011': 11,
#  '90012': 12,
#  '90013': 13,
#  '90014': 14,
#  '90015': 15,
#  '90938': 938,
#  '90939': 939,
#  '90940': 940,
#  '90941': 941,
#  '90942': 942,
#  '90943': 943,
#  '90944': 944,
#  '90945': 945,
#  '90946': 946,
#  '90947': 947,
#  '90948': 948,
#  '90949': 949,
#  '90950': 950,
#  '90951': 951,
#  '90952': 952,
#  '90953': 953,
#  '90954': 954,
#  '90955': 955,
#  '90956': 956,
#  '90957': 957,
#  '90958': 958,
#  '90959': 959,
#  '90960': 960,
#  '90961': 961,
#  '90962': 962,
#  '90963': 963,
#  '90964': 964,
#  '90965': 965,
#  '90966': 966,
#  '90967': 967,
#  '90968': 968,
#  '90969': 969,
#  '90970': 970,
#  '90971': 971,
#  '90972': 972,
#  '90973': 973,
#  '90974': 974,
#  '90975': 975,
#  '90976': 976,
#  '90977': 977,
#  '90978': 978,
#  '90979': 979,
#  '90980': 980,
#  '90981': 981,
#  '90982': 982,
#  '90983': 983,
#  '90984': 984,
#  '90985': 985,
#  '90986': 986,
#  '90987': 987,
#  '90988': 988,
#  '90989': 989,
#  '90990': 990,
#  '90991': 991,
#  '90992': 992,
#  '90993': 993,
#  '90994': 994,
#  '90995': 995,
#  '90996': 996,
#  '90997': 997,
#  '90998': 998,
#  '90999': 999,
#  ...}

# %%
query_imnos
# Out:
# [314,
#  376,
#  175,
#  949,
#  818,
#  1374,
#  696,
#  464,
#  413,
#  356,
#  185,
#  284,
#  341,
#  783,
#  529,
#  721,
#  1298,
#  1437,
#  153,
#  581,
#  439,
#  841,
#  1069,
#  766,
#  359,
#  81,
#  126,
#  531,
#  503,
#  93,
#  222,
#  977,
#  180,
#  1246,
#  690,
#  669,
#  173,
#  484,
#  1464,
#  631,
#  1241,
#  41,
#  611,
#  1462,
#  518,
#  1210,
#  1264,
#  598,
#  1061,
#  616,
#  870,
#  1044,
#  1413,
#  255,
#  97,
#  752,
#  56,
#  710,
#  908,
#  501,
#  105,
#  1349,
#  836,
#  8,
#  438,
#  1329,
#  607,
#  132,
#  872,
#  1203,
#  1201,
#  767,
#  738,
#  1470,
#  1283,
#  632,
#  1468,
#  983,
#  618,
#  610,
#  498,
#  1386,
#  1182,
#  1346,
#  27,
#  155,
#  315,
#  250,
#  635,
#  1065,
#  411,
#  558,
#  1312,
#  650,
#  358,
#  259,
#  1465,
#  722,
#  1471,
#  888,
#  37,
#  149,
#  1454,
#  932,
#  468,
#  1233,
#  289,
#  445,
#  1432,
#  441,
#  63,
#  843,
#  443,
#  174,
#  1031,
#  1124,
#  214,
#  715,
#  1272,
#  1164,
#  1002,
#  511,
#  1467,
#  1003,
#  833,
#  106,
#  217,
#  16,
#  954,
#  463,
#  1335,
#  509,
#  340,
#  1118,
#  383,
#  1096,
#  172,
#  585,
#  1393,
#  163,
#  1435,
#  357,
#  385,
#  457,
#  118,
#  1333,
#  1366,
#  107,
#  60,
#  1165,
#  994,
#  911,
#  307,
#  380,
#  306,
#  320,
#  1209,
#  1074,
#  1240,
#  481,
#  1394,
#  591,
#  1324,
#  646,
#  1477,
#  416,
#  1025,
#  1476,
#  1053,
#  425,
#  213,
#  1396,
#  1046,
#  455,
#  902,
#  17,
#  810,
#  1151,
#  329,
#  636,
#  171,
#  1106,
#  349,
#  322,
#  1345,
#  620,
#  875,
#  381,
#  1012,
#  522,
#  865,
#  1245,
#  1171,
#  101,
#  739,
#  1070,
#  914,
#  1303,
#  713,
#  324,
#  1068,
#  65,
#  743,
#  447,
#  892,
#  160,
#  1273,
#  716,
#  30,
#  775,
#  791,
#  603,
#  1011,
#  83,
#  184,
#  490,
#  718,
#  583,
#  211,
#  692,
#  723,
#  1212,
#  1094,
#  22,
#  594,
#  64,
#  44,
#  460,
#  1028,
#  485,
#  538,
#  412,
#  1008,
#  1040,
#  39,
#  867,
#  933,
#  709,
#  367,
#  182,
#  1439,
#  482,
#  290,
#  972,
#  1019,
#  1372,
#  826,
#  472,
#  1086,
#  1317]

# %%
IMG_IDS[query_imnos[0]]
# Out:
# '90314'

# %%
gt_data[IMG_IDS[query_imnos[0]]]
# Out:
# ['90989', '91259']

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Using `query_imnos`, you can now select the descriptors of the query images from the precomputed array `global_image_descr`.**
# </div>

# %%
# TODO select the descriptors of the query images
# query_vectors = ...
query_vectors = global_image_descr[query_imnos]

# %% [markdown]
# ### 6.4 Run the query

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Run a search query for all query images using our search engine. Ask for 9 neighbors because we want 8 real results and we will later remove the query from the list of results (we expect it the be the first result here, because our queries belong to our database for testing purposes).**
# </div>

# %%
# TODO
# get the 9 (8 real) NNs for all query images
# distances, results = search_engine....
distances, results = search_engine.kneighbors(query_vectors, return_distance=True, n_neighbors = 9)
distances.shape, results.shape
# Out:
# ((250, 9), (250, 9))

# %% [markdown]
# We expect here a shape of `(250, 9)` for the results.

# %% [markdown]
# ### 6.4 Evaluate the performance using mAP
# The mean average precision is the mean of the AP computed for each query.
# The AP is the area under the precision-recall curve.
#
# For each query, we will therefore sum the areas of the trapezoids between each recall values.

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Complete the code below to compute the mean average precision of our search engine on the training set.**
#
# Hint: you should get a value much higher than what random results would produce ($0.001$ in our tests but you can simulate this yourself).
# </div>

# %%
# TODO complete this code
aps = []  # list of average precisions for all queries
for qimno, qres in zip(query_imnos, results):
    qname = IMG_IDS[qimno]
#     print("query:", qname)
    # collect the positive results in the dataset
    # the positives have the same prefix as the query image
    positive_results = [imgid_to_index[img_id] for img_id in gt_data[IMG_IDS[qimno]]]
#     print("positive_results:", positive_results)
#     print("qres:", qres)
    #
    # ranks of positives. We skip the result #0, assumed to be the query image
    ranks = [i for i, res in enumerate(qres[1:]) if res in positive_results]
#     print("ranks:", ranks)
    #
    # accumulate trapezoids with this basis
    #recall_step = 1.0 / len(???)  # FIXME what is the size of a step?
    recall_step = 1.0 / len(positive_results)
    ap = 0
    for ntp, rank in enumerate(ranks):
        # ntp = nb of true positives so far
        # rank = nb of retrieved items so far
        # y-size on left side of trapezoid:
        precision_0 = ntp/float(rank) if rank > 0 else 1.0
        # y-size on right side of trapezoid:
        precision_1 = (ntp + 1) / float(rank + 1)
        #ap += ???  # FIXME what is the area under the PR curve?
        ap += (recall_step * (precision_0 + precision_1)) / 2.0
    print("query %s, AP = %.3f" % (qname, ap))
    aps.append(ap)

# print("mean AP = %.3f" % ???)  # FIXME mean average precision
print("mean AP = %.3f" % np.mean(ap))
# Out:
# query 90314, AP = 0.050
# query 90376, AP = 1.000
# query 90175, AP = 0.000
# query 90949, AP = 1.000
# query 90818, AP = 0.000
# query 91374, AP = 0.000
# query 90696, AP = 1.000
# query 90464, AP = 1.000
# query 90413, AP = 0.000
# query 90356, AP = 1.000
# query 90185, AP = 0.000
# query 90284, AP = 1.000
# query 90341, AP = 0.167
# query 90783, AP = 0.000
# query 90529, AP = 1.000
# query 90721, AP = 1.000
# query 91298, AP = 1.000
# query 91437, AP = 1.000
# query 90153, AP = 0.167
# query 90581, AP = 0.000
# query 90439, AP = 1.000
# query 90841, AP = 0.000
# query 91069, AP = 0.500
# query 90766, AP = 0.667
# query 90359, AP = 0.083
# query 90081, AP = 1.000
# query 90126, AP = 0.100
# query 90531, AP = 1.000
# query 90503, AP = 0.000
# query 90093, AP = 0.000
# query 90222, AP = 0.000
# query 90977, AP = 0.333
# query 90180, AP = 0.000
# query 91246, AP = 0.000
# query 90690, AP = 1.000
# query 90669, AP = 0.817
# query 90173, AP = 1.000
# query 90484, AP = 0.613
# query 91464, AP = 0.167
# query 90631, AP = 0.246
# query 91241, AP = 1.000
# query 90041, AP = 1.000
# query 90611, AP = 0.000
# query 91462, AP = 1.000
# query 90518, AP = 0.000
# query 91210, AP = 0.292
# query 91264, AP = 0.000
# query 90598, AP = 1.000
# query 91061, AP = 0.500
# query 90616, AP = 1.000
# query 90870, AP = 0.062
# query 91044, AP = 0.000
# query 91413, AP = 0.000
# query 90255, AP = 0.000
# query 90097, AP = 1.000
# query 90752, AP = 1.000
# query 90056, AP = 1.000
# query 90710, AP = 0.250
# query 90908, AP = 0.000
# query 90501, AP = 0.000
# query 90105, AP = 0.500
# query 91349, AP = 0.000
# query 90836, AP = 1.000
# query 90008, AP = 0.000
# query 90438, AP = 0.033
# query 91329, AP = 1.000
# query 90607, AP = 0.167
# query 90132, AP = 0.396
# query 90872, AP = 1.000
# query 91203, AP = 1.000
# query 91201, AP = 0.000
# query 90767, AP = 1.000
# query 90738, AP = 0.472
# query 91470, AP = 0.000
# query 91283, AP = 1.000
# query 90632, AP = 1.000
# query 91468, AP = 1.000
# query 90983, AP = 0.000
# query 90618, AP = 0.000
# query 90610, AP = 0.000
# query 90498, AP = 1.000
# query 91386, AP = 0.000
# query 91182, AP = 0.000
# query 90101, AP = 0.000
# query 90739, AP = 1.000
# query 91070, AP = 0.250
# query 90914, AP = 0.693
# query 91303, AP = 0.000
# query 90713, AP = 0.000
# query 90324, AP = 0.000
# query 91068, AP = 0.000
# query 90065, AP = 1.000
# query 90743, AP = 0.000
# query 90447, AP = 1.000
# query 90892, AP = 1.000
# query 90160, AP = 0.062
# query 91273, AP = 0.000
# query 90716, AP = 0.083
# query 90030, AP = 0.250
# query 90775, AP = 1.000
# query 90791, AP = 0.000
# query 90603, AP = 0.167
# query 91011, AP = 0.000
# query 90083, AP = 0.000
# query 90184, AP = 0.908
# query 90490, AP = 1.000
# query 90718, AP = 1.000
# query 90583, AP = 0.000
# query 90211, AP = 0.000
# query 90692, AP = 1.000
# query 90723, AP = 0.000
# query 91212, AP = 0.500
# query 91094, AP = 0.083
# query 90022, AP = 0.000
# query 90594, AP = 1.000
# query 90064, AP = 0.331
# query 90044, AP = 1.000
# query 90460, AP = 0.019
# query 91028, AP = 1.000
# query 90485, AP = 1.000
# query 90538, AP = 0.333
# query 90412, AP = 0.000
# query 91008, AP = 0.400
# query 91040, AP = 1.000
# query 90039, AP = 0.000
# query 90867, AP = 1.000
# query 90933, AP = 0.000
# query 90709, AP = 0.167
# query 90367, AP = 0.000
# query 90182, AP = 0.000
# query 91439, AP = 0.000
# query 90482, AP = 0.000
# query 90290, AP = 0.000
# query 90972, AP = 1.000
# query 91019, AP = 1.000
# query 91372, AP = 0.167
# query 90826, AP = 0.000
# query 90472, AP = 0.000
# query 91086, AP = 0.000
# query 91317, AP = 0.250
# mean AP = 0.250

# %% [markdown]
# ## 7. Display some results
# We provide you with some code to display query results.

# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread

nrow = 8   # number of query images to show
nres = 8   # number of results per query

def show_image(imno, frame_color):
    im = imread(os.path.join(PATH_TO_RESOURCES, "thumbs", "%s.jpg" % IMG_IDS[imno]))
    plt.imshow(im)
    h, w = im.shape[:2]
    plt.plot([0, 0, w, w, 0], [0, h, h, 0, 0], frame_color, linewidth = 2)
    plt.axis('off')

# reduce the margins
plt.subplots_adjust(wspace = 0, hspace = 0,
                    top = 0.99, bottom = 0.01, left = 0.01, right = 0.99)

plt.figure(figsize=(16,10))
no = 1  # index current of subfigure
for qno in range(nrow):
    plt.subplot(nrow, nres + 1, no); no += 1
    # show query image with white outline
    qimno = query_imnos[qno]
    show_image(qimno, 'w')
    plt.title(IMG_IDS[qimno])
    for res_rank, qres in enumerate(results[qno, 1:nres+1]): # 1:nres+1 => skip query from results
        plt.subplot(nrow, nres + 1, no); no += 1
        # use image name to determine if it is a TP or FP result
        is_ok = IMG_IDS[qres] in gt_data[IMG_IDS[qimno]]
        show_image(qres, 'g' if is_ok else 'r')
#         plt.title("%0.2f" % (distances[qno,res_rank]))
        plt.title(IMG_IDS[qres])

plt.show()

# %% [markdown]
# ## 8. Compute the best results for the test queries
# You are now ready to process the test data for the grading.
#
# We provide you with a set of query ids, and you must produce the list of most releveant results for each.

# %%
test_queries = None
with open(os.path.join(PATH_TO_RESOURCES, "queries_for_grading.json")) as qin:
    test_queries = json.load(qin)
test_queries[:10]
# Out:
# ['91401',
#  '91274',
#  '90136',
#  '91071',
#  '91221',
#  '90274',
#  '90240',
#  '90662',
#  '90169',
#  '90751']

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **For each query, compute the list of best results.**
# </div>

# %%
# TODO everything
# ...
# distances, test_results = ...
query_imnos_test = [imgid_to_index[query_id] for query_id in test_queries]
query_vectors_test = global_image_descr[query_imnos_test]
distances, test_results = search_engine.kneighbors(query_vectors_test, return_distance=True, n_neighbors = 9)
distances.shape, test_results.shape
# Out:
# ((250, 9), (250, 9))

# %% [markdown]
# <div style="overflow: auto; border-style: dotted; border-width: 1px; padding: 10px; margin: 10px 0px">
# <img alt="work" src='img/work.png' style='float: left; margin-right: 20px'>
#
# **Display your results to control them visually. Make sure you really perform this step because the train and test sets have the same size here, and it is easy to get confused and submit the wrong set!**
# </div>

# %%
# # TODO
# from matplotlib import pyplot as plt
# from matplotlib.image import imread

# nrow = 8   # number of query images to show
# nres = 8   # number of results per query

# def show_image(imno, frame_color):
#     im = imread(os.path.join(PATH_TO_RESOURCES, "thumbs", "%s.jpg" % IMG_IDS[imno]))
#     plt.imshow(im)
#     h, w = im.shape[:2]
#     plt.plot([0, 0, w, w, 0], [0, h, h, 0, 0], frame_color, linewidth = 2)
#     plt.axis('off')

# reduce the margins
plt.subplots_adjust(wspace = 0, hspace = 0,
                    top = 0.99, bottom = 0.01, left = 0.01, right = 0.99)

plt.figure(figsize=(16,10))
no = 1  # index current of subfigure
for qno in range(nrow):
    plt.subplot(nrow, nres + 1, no); no += 1
    # show query image with white outline
    qimno = query_imnos_test[qno]
    show_image(qimno, 'w')
    plt.title(IMG_IDS[qimno])
    for res_rank, qres in enumerate(test_results[qno, 1:nres+1]): # 1:nres+1 => skip query from results
        plt.subplot(nrow, nres + 1, no); no += 1
        # use image name to determine if it is a TP or FP result
        is_ok = IMG_IDS[qres] in test_queries
        show_image(qres, 'g' if is_ok else 'r')
#         plt.title("%0.2f" % (distances[qno,res_rank]))
        plt.title(IMG_IDS[qres])

plt.show()

# %% [markdown]
# ## 9. Export the results for the test queries
#
# Here is some code to export your results in the appropriate format.
#
# **Do not forget to submit them!**

# %%
results = {query_id: [IMG_IDS[ri] for ri in results_ids[1:]]
           for query_id,results_ids in zip(test_queries, test_results)}
results
# Out:
# {'91401': ['90198',
#   '91164',
#   '91337',
#   '90408',
#   '90806',
#   '90415',
#   '90443',
#   '91227'],
#  '91274': ['90205',
#   '90032',
#   '91058',
#   '90756',
#   '90058',
#   '90652',
#   '91169',
#   '90153'],
#  '90136': ['90706',
#   '90912',
#   '90395',
#   '90090',
#   '90752',
#   '90594',
#   '90215',
#   '91063'],
#  '91071': ['90478',
#   '91020',
#   '90215',
#   '90034',
#   '90839',
#   '90748',
#   '90086',
#   '90395'],
#  '91221': ['90698',
#   '91445',
#   '90942',
#   '91189',
#   '90930',
#   '90344',
#   '90584',
#   '91384'],
#  '90274': ['91197',
#   '91171',
#   '90986',
#   '90163',
#   '91104',
#   '91305',
#   '91319',
#   '91415'],
#  '90240': ['90687',
#   '90990',
#   '91082',
#   '90425',
#   '90176',
#   '90330',
#   '91272',
#   '90793'],
#  '90662': ['91292',
#   '91400',
#   '91286',
#   '91239',
#   '90191',
#   '90096',
#   '91481',
#   '91211'],
#  '90169': ['90998',
#   '90994',
#   '90995',
#   '90992',
#   '90997',
#   '90999',
#   '90990',
#   '91000'],
#  '90751': ['90829',
#   '90424',
#   '90884',
#   '90111',
#   '90335',
#   '91175',
#   '90909',
#   '90209'],
#  '91207': ['90806',
#   '90684',
#   '90988',
#   '90800',
#   '90330',
#   '91314',
#   '90470',
#   '90743'],
#  '90689': ['91179',
#   '90502',
#   '90114',
#   '90220',
#   '90725',
#   '90418',
#   '91475',
#   '91436'],
#  '90138': ['91416',
#   '90376',
#   '90674',
#   '90871',
#   '91235',
#   '90570',
#   '91050',
#   '91190'],
#  '91178': ['90582',
#   '90690',
#   '90226',
#   '90930',
#   '91406',
#   '90401',
#   '91165',
#   '90227'],
#  '91449': ['90196',
#   '90548',
#   '91062',
#   '91052',
#   '90653',
#   '91457',
#   '91205',
#   '91159'],
#  '91062': ['91052',
#   '91449',
#   '90196',
#   '90548',
#   '90653',
#   '91457',
#   '90578',
#   '91198'],
#  '91481': ['90578',
#   '91215',
#   '90414',
#   '91018',
#   '91316',
#   '90573',
#   '90189',
#   '90548'],
#  '90541': ['91134',
#   '91052',
#   '90004',
#   '90476',
#   '90414',
#   '91062',
#   '90578',
#   '90318'],
#  '90850': ['91254',
#   '90639',
#   '90431',
#   '90808',
#   '91213',
#   '90492',
#   '90370',
#   '91469'],
#  '90869': ['90452',
#   '91100',
#   '90376',
#   '91296',
#   '90674',
#   '91368',
#   '90120',
#   '90463'],
#  '90728': ['90129',
#   '90487',
#   '91038',
#   '90758',
#   '90963',
#   '91203',
#   '90535',
#   '90885'],
#  '90533': ['90947',
#   '90330',
#   '90898',
#   '90922',
#   '90470',
#   '90810',
#   '90990',
#   '90806'],
#  '90590': ['90157',
#   '90187',
#   '91119',
#   '90838',
#   '91012',
#   '90342',
#   '90962',
#   '90235'],
#  '90906': ['90502',
#   '90955',
#   '90720',
#   '90220',
#   '90725',
#   '90855',
#   '90396',
#   '91004'],
#  '90717': ['90365',
#   '90152',
#   '90249',
#   '91486',
#   '90461',
#   '90058',
#   '90618',
#   '90411'],
#  '91043': ['90019',
#   '91396',
#   '90962',
#   '90414',
#   '90121',
#   '90498',
#   '90822',
#   '90537'],
#  '90459': ['91215',
#   '91414',
#   '90246',
#   '90626',
#   '90805',
#   '90035',
#   '91018',
#   '90617'],
#  '90830': ['90593',
#   '91474',
#   '91211',
#   '90829',
#   '90296',
#   '90992',
#   '91256',
#   '90909'],
#  '90705': ['90415',
#   '90050',
#   '90100',
#   '90454',
#   '90800',
#   '90417',
#   '90268',
#   '91437'],
#  '90798': ['90541',
#   '90480',
#   '91281',
#   '91134',
#   '90004',
#   '91396',
#   '90318',
#   '90092'],
#  '90993': ['90087',
#   '90330',
#   '91026',
#   '90268',
#   '91467',
#   '90837',
#   '90126',
#   '90806'],
#  '90965': ['90795',
#   '90641',
#   '90663',
#   '90886',
#   '90508',
#   '90777',
#   '90526',
#   '90989'],
#  '91347': ['91077',
#   '91272',
#   '90373',
#   '90352',
#   '90880',
#   '91133',
#   '90276',
#   '91076'],
#  '90154': ['91147',
#   '90058',
#   '90152',
#   '90517',
#   '90654',
#   '91225',
#   '90756',
#   '91072'],
#  '90486': ['91467',
#   '91337',
#   '90268',
#   '91284',
#   '90966',
#   '90183',
#   '90454',
#   '90013'],
#  '91190': ['90330',
#   '90255',
#   '90033',
#   '90470',
#   '91437',
#   '91314',
#   '90540',
#   '90966'],
#  '90423': ['91236',
#   '90286',
#   '90951',
#   '90465',
#   '91395',
#   '91231',
#   '91218',
#   '90948'],
#  '90675': ['91194',
#   '91170',
#   '90353',
#   '91319',
#   '90474',
#   '91010',
#   '91360',
#   '90400'],
#  '90231': ['90011',
#   '90582',
#   '91406',
#   '90690',
#   '90226',
#   '90930',
#   '90401',
#   '90991'],
#  '90245': ['90801',
#   '90151',
#   '90334',
#   '91488',
#   '90961',
#   '90852',
#   '91399',
#   '90184'],
#  '91125': ['90810',
#   '90990',
#   '91077',
#   '90687',
#   '90087',
#   '91337',
#   '90806',
#   '90330'],
#  '91166': ['91083',
#   '90758',
#   '90608',
#   '90997',
#   '90377',
#   '90022',
#   '91228',
#   '90899'],
#  '90619': ['91269',
#   '90378',
#   '91205',
#   '91159',
#   '90377',
#   '91309',
#   '90280',
#   '91153'],
#  '91262': ['90571',
#   '91092',
#   '90145',
#   '90442',
#   '91183',
#   '91414',
#   '90477',
#   '91132'],
#  '91183': ['91092',
#   '90145',
#   '91462',
#   '90664',
#   '90442',
#   '90089',
#   '90571',
#   '91262'],
#  '91410': ['90076',
#   '91114',
#   '90614',
#   '90023',
#   '91239',
#   '90900',
#   '90522',
#   '90576'],
#  '90296': ['90990',
#   '91482',
#   '90724',
#   '90687',
#   '90552',
#   '90598',
#   '90725',
#   '90793'],
#  '90068': ['90909',
#   '90608',
#   '91415',
#   '90895',
#   '90168',
#   '90209',
#   '90028',
#   '90650'],
#  '90080': ['90625',
#   '91332',
#   '91038',
#   '90298',
#   '90484',
#   '90731',
#   '90599',
#   '90198'],
#  '91110': ['91194',
#   '90481',
#   '90842',
#   '90791',
#   '90676',
#   '90816',
#   '90889',
#   '90564'],
#  '90072': ['90973',
#   '90063',
#   '91338',
#   '90911',
#   '91370',
#   '90930',
#   '90916',
#   '90563'],
#  '90851': ['90930',
#   '90226',
#   '91049',
#   '90916',
#   '90501',
#   '91008',
#   '90203',
#   '90584'],
#  '90133': ['90700',
#   '91437',
#   '90176',
#   '90530',
#   '90330',
#   '90470',
#   '90977',
#   '90631'],
#  '91479': ['91436',
#   '90256',
#   '91464',
#   '90114',
#   '90955',
#   '90524',
#   '91169',
#   '91424'],
#  '90800': ['90415',
#   '90806',
#   '90922',
#   '90898',
#   '90743',
#   '90532',
#   '90087',
#   '90470'],
#  '90807': ['90599',
#   '90135',
#   '90630',
#   '91293',
#   '90731',
#   '91094',
#   '90368',
#   '90826'],
#  '90595': ['91232',
#   '90355',
#   '91481',
#   '90537',
#   '91215',
#   '91044',
#   '91316',
#   '91018'],
#  '91155': ['91302',
#   '91205',
#   '90378',
#   '91159',
#   '91185',
#   '90636',
#   '90377',
#   '90171'],
#  '91338': ['91370',
#   '91128',
#   '90063',
#   '90226',
#   '91304',
#   '90930',
#   '90563',
#   '91406'],
#  '90615': ['90415',
#   '90268',
#   '91467',
#   '90800',
#   '90013',
#   '90532',
#   '90126',
#   '91077'],
#  '90292': ['90711',
#   '91038',
#   '91332',
#   '90376',
#   '90135',
#   '90951',
#   '91157',
#   '90636'],
#  '90304': ['90487',
#   '91159',
#   '91254',
#   '91205',
#   '90691',
#   '91044',
#   '90378',
#   '90619'],
#  '90036': ['90493',
#   '91355',
#   '90255',
#   '91284',
#   '90853',
#   '91442',
#   '90429',
#   '90033'],
#  '91013': ['90773',
#   '90975',
#   '90360',
#   '91112',
#   '91205',
#   '90849',
#   '90233',
#   '91159'],
#  '90871': ['90159',
#   '90376',
#   '90674',
#   '91416',
#   '90138',
#   '90550',
#   '90537',
#   '91254'],
#  '90935': ['91219',
#   '91348',
#   '90997',
#   '90909',
#   '90284',
#   '90608',
#   '91288',
#   '90763'],
#  '91363': ['91143',
#   '90224',
#   '90764',
#   '90033',
#   '90990',
#   '91452',
#   '91283',
#   '91395'],
#  '90866': ['91218',
#   '90284',
#   '91428',
#   '90909',
#   '90377',
#   '90650',
#   '90386',
#   '90608'],
#  '90420': ['90071',
#   '90330',
#   '91466',
#   '90425',
#   '90814',
#   '90470',
#   '90990',
#   '91190'],
#  '90391': ['90909',
#   '91288',
#   '91396',
#   '91139',
#   '90471',
#   '90121',
#   '90537',
#   '90871'],
#  '90873': ['90159',
#   '90035',
#   '90613',
#   '90196',
#   '91256',
#   '91307',
#   '91228',
#   '90548'],
#  '90884': ['90335',
#   '91175',
#   '91020',
#   '91471',
#   '90111',
#   '91191',
#   '90453',
#   '90209'],
#  '90000': ['90306',
#   '90401',
#   '91165',
#   '91384',
#   '90227',
#   '90930',
#   '90049',
#   '90584'],
#  '91248': ['91293',
#   '90807',
#   '90630',
#   '90135',
#   '90188',
#   '90376',
#   '91010',
#   '91096'],
#  '90449': ['90077',
#   '91446',
#   '90128',
#   '90203',
#   '90071',
#   '90930',
#   '90991',
#   '91461'],
#  '90742': ['91336',
#   '90434',
#   '90937',
#   '90422',
#   '90797',
#   '90180',
#   '90952',
#   '90361'],
#  '91202': ['90865',
#   '90823',
#   '90400',
#   '90346',
#   '90920',
#   '90383',
#   '90630',
#   '91010'],
#  '90771': ['90627',
#   '90722',
#   '90090',
#   '90789',
#   '91288',
#   '90608',
#   '90909',
#   '90693'],
#  '91322': ['90356',
#   '90962',
#   '90573',
#   '90019',
#   '90159',
#   '90537',
#   '90968',
#   '91184'],
#  '90309': ['91171',
#   '90678',
#   '90583',
#   '90428',
#   '90461',
#   '91075',
#   '90685',
#   '91369'],
#  '91196': ['91017',
#   '90629',
#   '90032',
#   '90331',
#   '90197',
#   '90785',
#   '90998',
#   '90706'],
#  '90799': ['90330',
#   '90898',
#   '90922',
#   '90977',
#   '90631',
#   '90533',
#   '91251',
#   '90050'],
#  '90276': ['91026',
#   '90087',
#   '90818',
#   '91082',
#   '90567',
#   '90641',
#   '90323',
#   '91272'],
#  '91091': ['90424',
#   '90693',
#   '90909',
#   '90090',
#   '91288',
#   '90753',
#   '90752',
#   '91419'],
#  '90781': ['91207',
#   '90540',
#   '90330',
#   '90770',
#   '90581',
#   '90470',
#   '90691',
#   '90988'],
#  '90021': ['90176',
#   '90255',
#   '90990',
#   '90872',
#   '90815',
#   '90175',
#   '91337',
#   '91297'],
#  '91287': ['90690',
#   '90600',
#   '91165',
#   '90226',
#   '90582',
#   '90930',
#   '90401',
#   '91406'],
#  '90948': ['91231',
#   '90439',
#   '91203',
#   '91251',
#   '91395',
#   '90041',
#   '91464',
#   '90951'],
#  '90734': ['90958',
#   '91021',
#   '90998',
#   '90400',
#   '90597',
#   '90782',
#   '90630',
#   '90346'],
#  '90400': ['90630',
#   '91010',
#   '90823',
#   '90261',
#   '91194',
#   '90353',
#   '90807',
#   '91293'],
#  '90998': ['91192',
#   '90630',
#   '90734',
#   '90400',
#   '90346',
#   '90606',
#   '90958',
#   '90912'],
#  '90893': ['90594',
#   '90642',
#   '91063',
#   '90090',
#   '90056',
#   '90789',
#   '90286',
#   '90722'],
#  '90476': ['91368',
#   '91044',
#   '90834',
#   '91213',
#   '90553',
#   '90639',
#   '91296',
#   '91134'],
#  '91296': ['91248',
#   '90376',
#   '90120',
#   '91389',
#   '90869',
#   '90826',
#   '91096',
#   '90674'],
#  '91442': ['90790',
#   '90966',
#   '90552',
#   '90853',
#   '90303',
#   '90013',
#   '91260',
#   '90796'],
#  '91253': ['90581',
#   '90330',
#   '91251',
#   '91318',
#   '90988',
#   '90050',
#   '90540',
#   '91094'],
#  '90040': ['91039',
#   '90321',
#   '90691',
#   '90684',
#   '90234',
#   '91207',
#   '90487',
#   '91388'],
#  '90853': ['90601',
#   '91260',
#   '90796',
#   '90183',
#   '91352',
#   '90790',
#   '90978',
#   '91442'],
#  '90454': ['91284',
#   '90268',
#   '91260',
#   '90532',
#   '90837',
#   '90013',
#   '91355',
#   '90588'],
#  '90450': ['90804',
#   '90530',
#   '90563',
#   '90133',
#   '90176',
#   '90740',
#   '90678',
#   '90224'],
#  '90588': ['91140',
#   '91250',
#   '91330',
#   '90183',
#   '90796',
#   '91158',
#   '91284',
#   '90454'],
#  '90515': ['91475',
#   '90938',
#   '91383',
#   '90904',
#   '91004',
#   '90854',
#   '91355',
#   '90506'],
#  '90520': ['91415',
#   '91194',
#   '90277',
#   '90644',
#   '90865',
#   '90118',
#   '91170',
#   '90920'],
#  '90143': ['90059',
#   '91371',
#   '90777',
#   '90840',
#   '90886',
#   '90872',
#   '91473',
#   '91076'],
#  '90899': ['90997',
#   '90377',
#   '90280',
#   '91153',
#   '90758',
#   '91309',
#   '90201',
#   '90284'],
#  '90347': ['90489',
#   '91310',
#   '90532',
#   '90956',
#   '90897',
#   '90806',
#   '90087',
#   '91130'],
#  '90087': ['91026',
#   '90532',
#   '91158',
#   '91284',
#   '90268',
#   '91260',
#   '90183',
#   '90415'],
#  '90013': ['90268',
#   '91355',
#   '91284',
#   '90454',
#   '90183',
#   '90837',
#   '91442',
#   '91260'],
#  '90832': ['90519',
#   '90473',
#   '90687',
#   '90790',
#   '90303',
#   '90990',
#   '90966',
#   '91442'],
#  '90927': ['91267',
#   '91176',
#   '90396',
#   '90998',
#   '90855',
#   '90955',
#   '91424',
#   '90764'],
#  '90002': ['91365',
#   '90303',
#   '90790',
#   '90687',
#   '90966',
#   '90236',
#   '90183',
#   '91158'],
#  '90730': ['90038',
#   '90719',
#   '90212',
#   '91056',
#   '90281',
#   '91343',
#   '90379',
#   '90500'],
#  '90564': ['90212',
#   '90581',
#   '90636',
#   '90719',
#   '91210',
#   '91193',
#   '90692',
#   '90415'],
#  '90277': ['91415',
#   '90118',
#   '91367',
#   '91194',
#   '90865',
#   '90644',
#   '90920',
#   '90238'],
#  '90712': ['90234',
#   '90033',
#   '91340',
#   '90439',
#   '91231',
#   '90465',
#   '90612',
#   '90951'],
#  '91123': ['90726',
#   '90907',
#   '90421',
#   '90735',
#   '90276',
#   '90272',
#   '90323',
#   '90663'],
#  '90969': ['90330',
#   '91130',
#   '90886',
#   '91272',
#   '90862',
#   '90922',
#   '90898',
#   '90880'],
#  '90421': ['90825',
#   '90272',
#   '90622',
#   '90323',
#   '90663',
#   '90795',
#   '91123',
#   '90818'],
#  '90796': ['90183',
#   '91158',
#   '90790',
#   '90853',
#   '91260',
#   '91140',
#   '90303',
#   '90904'],
#  '90508': ['91337',
#   '90795',
#   '90641',
#   '90793',
#   '90989',
#   '90175',
#   '90483',
#   '90687'],
#  '91412': ['90346',
#   '90630',
#   '91096',
#   '91293',
#   '91010',
#   '90650',
#   '91064',
#   '90244'],
#  '91102': ['90582',
#   '90690',
#   '91217',
#   '90226',
#   '91406',
#   '90600',
#   '90123',
#   '91076'],
#  '90706': ['90395',
#   '90752',
#   '91058',
#   '91317',
#   '90468',
#   '91345',
#   '91117',
#   '90327'],
#  '90805': ['90573',
#   '90189',
#   '90211',
#   '90356',
#   '90024',
#   '90441',
#   '90929',
#   '91414'],
#  '90179': ['90682',
#   '90180',
#   '91447',
#   '90184',
#   '90434',
#   '91156',
#   '90485',
#   '90586'],
#  '90868': ['91404',
#   '91035',
#   '90099',
#   '90882',
#   '90464',
#   '90689',
#   '90502',
#   '91331'],
#  '90145': ['90308',
#   '90442',
#   '90477',
#   '91462',
#   '91092',
#   '90664',
#   '91414',
#   '91183'],
#  '90614': ['90121',
#   '90551',
#   '91288',
#   '90608',
#   '90962',
#   '90111',
#   '90576',
#   '90753'],
#  '90074': ['90109',
#   '91055',
#   '90363',
#   '90330',
#   '90440',
#   '90100',
#   '90126',
#   '90373'],
#  '91051': ['90823',
#   '90920',
#   '90865',
#   '91293',
#   '90400',
#   '90261',
#   '90346',
#   '91010'],
#  '91067': ['90418',
#   '91442',
#   '90672',
#   '90790',
#   '90220',
#   '90502',
#   '90303',
#   '90268'],
#  '90624': ['90910',
#   '90159',
#   '91273',
#   '91221',
#   '91159',
#   '90698',
#   '90428',
#   '90436'],
#  '91480': ['90190',
#   '90286',
#   '90722',
#   '90135',
#   '90465',
#   '90951',
#   '90630',
#   '91241'],
#  '90057': ['90948',
#   '90700',
#   '90439',
#   '90275',
#   '90559',
#   '90530',
#   '91145',
#   '91398'],
#  '91321': ['90028',
#   '90346',
#   '90704',
#   '90961',
#   '90424',
#   '90007',
#   '90375',
#   '91095'],
#  '91334': ['91433',
#   '91048',
#   '90093',
#   '91037',
#   '91186',
#   '90468',
#   '90802',
#   '90338'],
#  '91146': ['90608',
#   '91172',
#   '91195',
#   '90736',
#   '90752',
#   '90424',
#   '90375',
#   '90028'],
#  '90661': ['91463',
#   '90194',
#   '90299',
#   '90673',
#   '90909',
#   '90111',
#   '91150',
#   '90424'],
#  '90656': ['91469',
#   '90539',
#   '91450',
#   '90573',
#   '90578',
#   '90968',
#   '90548',
#   '90196'],
#  '90046': ['90950',
#   '91142',
#   '90802',
#   '91378',
#   '91274',
#   '91275',
#   '90032',
#   '90205'],
#  '90678': ['90461',
#   '90249',
#   '90153',
#   '90428',
#   '91072',
#   '90524',
#   '90632',
#   '90583'],
#  '90453': ['91175',
#   '91020',
#   '90884',
#   '90839',
#   '91471',
#   '91172',
#   '91300',
#   '91191'],
#  '90649': ['90192',
#   '90170',
#   '91181',
#   '90477',
#   '91138',
#   '90865',
#   '91006',
#   '91309'],
#  '91474': ['90748',
#   '90839',
#   '91020',
#   '91175',
#   '90252',
#   '90884',
#   '90207',
#   '90962'],
#  '90258': ['91139',
#   '91172',
#   '91471',
#   '90162',
#   '90028',
#   '90608',
#   '91211',
#   '90884'],
#  '90431': ['90159',
#   '90356',
#   '90968',
#   '90035',
#   '91322',
#   '90871',
#   '90573',
#   '91481'],
#  '90305': ['90336',
#   '91037',
#   '90346',
#   '91028',
#   '91064',
#   '90093',
#   '90592',
#   '90088'],
#  '90748': ['90839',
#   '91020',
#   '91474',
#   '91071',
#   '91175',
#   '90884',
#   '90453',
#   '90405'],
#  '91392': ['90096',
#   '90026',
#   '90008',
#   '91134',
#   '91296',
#   '90039',
#   '90575',
#   '91416'],
#  '90239': ['91125',
#   '91077',
#   '90425',
#   '90349',
#   '91133',
#   '90872',
#   '90176',
#   '91272'],
#  '90295': ['90018',
#   '90691',
#   '90096',
#   '90466',
#   '90510',
#   '90619',
#   '90695',
#   '91044'],
#  '90900': ['90954',
#   '90865',
#   '91089',
#   '90659',
#   '90197',
#   '90477',
#   '91101',
#   '91249'],
#  '91460': ['90898',
#   '90922',
#   '90031',
#   '90687',
#   '90990',
#   '90175',
#   '90330',
#   '91467'],
#  '90759': ['90813',
#   '90758',
#   '91348',
#   '90997',
#   '90636',
#   '90377',
#   '91185',
#   '91309'],
#  '90858': ['90681',
#   '91010',
#   '91293',
#   '90120',
#   '91096',
#   '91094',
#   '90297',
#   '90807'],
#  '91122': ['90555',
#   '90210',
#   '91156',
#   '90334',
#   '90961',
#   '90852',
#   '91488',
#   '91415'],
#  '90396': ['90855',
#   '90282',
#   '90955',
#   '90319',
#   '90720',
#   '91464',
#   '90041',
#   '91468'],
#  '90785': ['90326',
#   '90346',
#   '90197',
#   '90895',
#   '90028',
#   '90034',
#   '90734',
#   '91087'],
#  '91373': ['91454',
#   '90188',
#   '91437',
#   '90330',
#   '90470',
#   '90268',
#   '90894',
#   '90826'],
#  '90054': ['90916',
#   '90201',
#   '91074',
#   '90899',
#   '91049',
#   '91153',
#   '90377',
#   '90997'],
#  '90572': ['90009',
#   '91320',
#   '90346',
#   '90333',
#   '90064',
#   '90197',
#   '90644',
#   '91208'],
#  '91457': ['91062',
#   '91228',
#   '90653',
#   '90213',
#   '90548',
#   '91449',
#   '90811',
#   '90555'],
#  '91103': ['90670',
#   '91046',
#   '90151',
#   '90878',
#   '91112',
#   '90406',
#   '90204',
#   '90107'],
#  '90131': ['90288',
#   '91408',
#   '91335',
#   '90238',
#   '90739',
#   '91008',
#   '90118',
#   '90772'],
#  '90789': ['90693',
#   '90090',
#   '90630',
#   '90594',
#   '91129',
#   '91064',
#   '91063',
#   '91360'],
#  '91265': ['90655',
#   '90927',
#   '90955',
#   '90580',
#   '90061',
#   '91424',
#   '90524',
#   '90685'],
#  '90467': ['91109',
#   '91087',
#   '91484',
#   '91188',
#   '90888',
#   '90605',
#   '90958',
#   '90316'],
#  '90103': ['90648',
#   '90683',
#   '90912',
#   '91415',
#   '91266',
#   '90592',
#   '90346',
#   '91170'],
#  '90592': ['90591',
#   '91360',
#   '90630',
#   '91037',
#   '91194',
#   '90648',
#   '90090',
#   '90998'],
#  '91138': ['91249',
#   '90630',
#   '91010',
#   '90650',
#   '90865',
#   '90400',
#   '90118',
#   '90807'],
#  '91289': ['90521',
#   '90569',
#   '90461',
#   '91169',
#   '90618',
#   '90428',
#   '90583',
#   '91190'],
#  '90402': ['90042',
#   '91218',
#   '91309',
#   '90758',
#   '91010',
#   '90178',
#   '90190',
#   '90030'],
#  '90535': ['90909',
#   '90594',
#   '90722',
#   '90090',
#   '90286',
#   '90642',
#   '90758',
#   '90763'],
#  '90586': ['90180',
#   '91030',
#   '91156',
#   '90485',
#   '91488',
#   '90337',
#   '90961',
#   '91447'],
#  '90045': ['90098',
#   '91447',
#   '90180',
#   '91163',
#   '90184',
#   '90881',
#   '90307',
#   '90852'],
#  '91421': ['91487',
#   '91291',
#   '90190',
#   '91015',
#   '91064',
#   '90831',
#   '90402',
#   '90333'],
#  '90642': ['90594',
#   '90090',
#   '91063',
#   '90722',
#   '91105',
#   '91011',
#   '90286',
#   '91037'],
#  '90703': ['90712',
#   '90691',
#   '91369',
#   '90711',
#   '91044',
#   '90292',
#   '90684',
#   '91368'],
#  '91327': ['91101',
#   '91273',
#   '90865',
#   '91228',
#   '90210',
#   '91074',
#   '91151',
#   '90334'],
#  '90207': ['90441',
#   '90929',
#   '90086',
#   '91120',
#   '90643',
#   '91175',
#   '90335',
#   '91191'],
#  '90146': ['91188',
#   '90064',
#   '91367',
#   '90961',
#   '91163',
#   '90184',
#   '91087',
#   '90954'],
#  '91441': ['91340',
#   '91464',
#   '90041',
#   '90855',
#   '90754',
#   '90612',
#   '90303',
#   '90948'],
#  '90768': ['90307',
#   '90563',
#   '91189',
#   '90881',
#   '90911',
#   '90361',
#   '90063',
#   '90485'],
#  '90987': ['91220',
#   '90526',
#   '90766',
#   '91227',
#   '90059',
#   '90872',
#   '91371',
#   '90886'],
#  '90344': ['90584',
#   '91221',
#   '90930',
#   '90306',
#   '91182',
#   '90049',
#   '91384',
#   '90227'],
#  '91213': ['90639',
#   '91368',
#   '90476',
#   '90553',
#   '90355',
#   '91134',
#   '91044',
#   '90975'],
#  '90112': ['90442',
#   '90477',
#   '91131',
#   '90028',
#   '90424',
#   '90197',
#   '91471',
#   '90111'],
#  '90294': ['90223',
#   '90487',
#   '90510',
#   '90721',
#   '90370',
#   '90758',
#   '90711',
#   '90975'],
#  '90996': ['90318',
#   '91316',
#   '91481',
#   '90578',
#   '90092',
#   '90414',
#   '90695',
#   '91232'],
#  '91116': ['90580',
#   '90999',
#   '91060',
#   '90153',
#   '91417',
#   '90712',
#   '91340',
#   '90652'],
#  '90584': ['90306',
#   '90930',
#   '91384',
#   '90344',
#   '90227',
#   '90942',
#   '91221',
#   '90916'],
#  '90422': ['90434',
#   '91336',
#   '90952',
#   '90589',
#   '90742',
#   '91447',
#   '90180',
#   '91156'],
#  '91490': ['90442',
#   '91068',
#   '90145',
#   '90558',
#   '90878',
#   '91397',
#   '90477',
#   '90192'],
#  '90679': ['90361',
#   '90151',
#   '90142',
#   '90184',
#   '91488',
#   '90558',
#   '90485',
#   '91059'],
#  '90111': ['91191',
#   '90209',
#   '91175',
#   '90884',
#   '90424',
#   '90335',
#   '90168',
#   '91471'],
#  '90197': ['90389',
#   '90333',
#   '91064',
#   '91170',
#   '90650',
#   '90909',
#   '90659',
#   '90424'],
#  '91131': ['91000',
#   '90909',
#   '91420',
#   '90538',
#   '90424',
#   '90168',
#   '90865',
#   '90025'],
#  '90746': ['90277',
#   '90823',
#   '91293',
#   '91194',
#   '91415',
#   '91235',
#   '90520',
#   '90807'],
#  '90845': ['90583',
#   '90425',
#   '90990',
#   '91452',
#   '90176',
#   '90224',
#   '90552',
#   '90133'],
#  '90053': ['90658',
#   '91176',
#   '91452',
#   '90303',
#   '90854',
#   '90749',
#   '90790',
#   '91179'],
#  '90545': ['90638',
#   '90856',
#   '90878',
#   '90204',
#   '90233',
#   '91356',
#   '90151',
#   '90375'],
#  '91237': ['90654',
#   '90376',
#   '91169',
#   '90286',
#   '91424',
#   '90674',
#   '91464',
#   '90058'],
#  '90262': ['90543',
#   '90475',
#   '90984',
#   '90788',
#   '90823',
#   '91079',
#   '90961',
#   '90007'],
#  '90372': ['90346',
#   '91000',
#   '90630',
#   '91010',
#   '90197',
#   '90606',
#   '91054',
#   '91051'],
#  '90559': ['91251',
#   '90439',
#   '90951',
#   '90948',
#   '90530',
#   '90465',
#   '91203',
#   '91247'],
#  '91152': ['90287',
#   '91380',
#   '90225',
#   '90889',
#   '90349',
#   '90842',
#   '90358',
#   '91153'],
#  '90626': ['91184',
#   '91018',
#   '91414',
#   '91198',
#   '90211',
#   '90477',
#   '90653',
#   '91215'],
#  '91453': ['91174',
#   '90749',
#   '90379',
#   '90764',
#   '90658',
#   '90281',
#   '90212',
#   '90038'],
#  '90749': ['91453',
#   '91174',
#   '90379',
#   '90281',
#   '90658',
#   '90038',
#   '90110',
#   '90764'],
#  '90283': ['90865',
#   '91104',
#   '91477',
#   '90358',
#   '91010',
#   '90354',
#   '91152',
#   '90823'],
#  '90051': ['91430',
#   '90891',
#   '90110',
#   '91174',
#   '90658',
#   '90762',
#   '90270',
#   '90183'],
#  '91455': ['91214',
#   '90956',
#   '90347',
#   '90149',
#   '90225',
#   '90919',
#   '91430',
#   '91380'],
#  '90229': ['90210',
#   '91062',
#   '91415',
#   '91449',
#   '90555',
#   '90954',
#   '91228',
#   '90589'],
#  '90874': ['90498',
#   '90537',
#   '90150',
#   '90555',
#   '90210',
#   '91040',
#   '91307',
#   '91242'],
#  '90685': ['90275',
#   '90955',
#   '91452',
#   '90114',
#   '90224',
#   '91398',
#   '90583',
#   '90033'],
#  '90886': ['90777',
#   '90795',
#   '90818',
#   '90483',
#   '90175',
#   '90641',
#   '91130',
#   '90989'],
#  '90392': ['90014',
#   '91382',
#   '91122',
#   '91132',
#   '90961',
#   '90555',
#   '91488',
#   '90852'],
#  '91132': ['90334',
#   '91420',
#   '90477',
#   '91351',
#   '91122',
#   '90954',
#   '91131',
#   '90392'],
#  '90995': ['91076',
#   '90425',
#   '90814',
#   '90077',
#   '91466',
#   '91270',
#   '90128',
#   '90990'],
#  '91016': ['90564',
#   '91193',
#   '90363',
#   '90691',
#   '90094',
#   '90719',
#   '90214',
#   '90341'],
#  '90012': ['90500',
#   '91343',
#   '90719',
#   '90038',
#   '90379',
#   '90212',
#   '90363',
#   '90658'],
#  '90647': ['90820',
#   '91006',
#   '91008',
#   '91369',
#   '90813',
#   '90233',
#   '91356',
#   '91159'],
#  '91343': ['90379',
#   '90281',
#   '90212',
#   '90719',
#   '90658',
#   '90500',
#   '90038',
#   '91174'],
#  '91290': ['91366',
#   '90886',
#   '90777',
#   '90795',
#   '90140',
#   '90818',
#   '90844',
#   '91076'],
#  '91446': ['90991',
#   '90077',
#   '90582',
#   '90930',
#   '91324',
#   '91165',
#   '90401',
#   '90128'],
#  '91402': ['90230',
#   '90321',
#   '90711',
#   '91044',
#   '90636',
#   '91159',
#   '91185',
#   '91251'],
#  '90765': ['90100',
#   '90762',
#   '90956',
#   '91093',
#   '90087',
#   '91026',
#   '90735',
#   '90532'],
#  '90762': ['90658',
#   '91365',
#   '91174',
#   '90956',
#   '90160',
#   '91158',
#   '90864',
#   '90212'],
#  '91093': ['90956',
#   '90762',
#   '90765',
#   '91026',
#   '90087',
#   '90100',
#   '90806',
#   '90415'],
#  '91007': ['91364',
#   '91371',
#   '90143',
#   '90059',
#   '90291',
#   '91394',
#   '90266',
#   '91397'],
#  '91115': ['90806',
#   '90564',
#   '91053',
#   '91130',
#   '90267',
#   '91483',
#   '90481',
#   '91210'],
#  '90904': ['90515',
#   '90796',
#   '90183',
#   '91355',
#   '90853',
#   '91383',
#   '90013',
#   '90506'],
#  '90070': ['90650',
#   '90308',
#   '90680',
#   '91249',
#   '90606',
#   '90954',
#   '90039',
#   '90197'],
#  '90328': ['90038',
#   '90658',
#   '91343',
#   '91174',
#   '90110',
#   '90500',
#   '91430',
#   '90749'],
#  '90553': ['91368',
#   '91044',
#   '91205',
#   '90487',
#   '90691',
#   '90378',
#   '90355',
#   '90834'],
#  '90702': ['90986',
#   '91090',
#   '91163',
#   '91170',
#   '91415',
#   '91447',
#   '91397',
#   '90852'],
#  '90757': ['90990',
#   '90918',
#   '90815',
#   '90778',
#   '90892',
#   '90925',
#   '90687',
#   '90767'],
#  '91022': ['90149',
#   '90221',
#   '90526',
#   '90302',
#   '91476',
#   '90163',
#   '91206',
#   '91097'],
#  '90819': ['90636',
#   '91193',
#   '90806',
#   '90581',
#   '90842',
#   '90264',
#   '90564',
#   '91185'],
#  '90121': ['90024',
#   '90962',
#   '90736',
#   '90342',
#   '91239',
#   '90187',
#   '90614',
#   '91119'],
#  '90623': ['91332',
#   '90298',
#   '90763',
#   '91038',
#   '90636',
#   '91185',
#   '91309',
#   '90465'],
#  '91057': ['90390',
#   '91394',
#   '91049',
#   '90995',
#   '91305',
#   '91356',
#   '90916',
#   '91393'],
#  '91418': ['90279',
#   '90630',
#   '90606',
#   '91398',
#   '90530',
#   '90135',
#   '90599',
#   '90807'],
#  '91170': ['91367',
#   '90064',
#   '91163',
#   '91415',
#   '91010',
#   '90920',
#   '91320',
#   '90474'],
#  '90219': ['91199',
#   '90135',
#   '90804',
#   '90188',
#   '90465',
#   '90951',
#   '90599',
#   '90630'],
#  '90353': ['91194',
#   '90630',
#   '90400',
#   '91010',
#   '91319',
#   '90599',
#   '91293',
#   '90804'],
#  '91010': ['91293',
#   '90630',
#   '90400',
#   '91194',
#   '90333',
#   '90424',
#   '90823',
#   '91064'],
#  '90831': ['90286',
#   '90517',
#   '90032',
#   '90696',
#   '91274',
#   '90652',
#   '90756',
#   '91398'],
#  '91064': ['90594',
#   '91010',
#   '90630',
#   '90789',
#   '90346',
#   '91063',
#   '91360',
#   '90650'],
#  '91299': ['90334',
#   '91156',
#   '91415',
#   '91163',
#   '90895',
#   '91090',
#   '91321',
#   '90961']}

# %%
EXPORT_PATH = "results.json"

# %%
with open(EXPORT_PATH, 'w') as outres:
    json.dump(results, outres, indent=1)
# !head $EXPORT_PATH
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Job done!
# Do you think you can improve the performance of your approach and get a better grading?
